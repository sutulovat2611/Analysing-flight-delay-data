# %% [markdown]
# # Table of contents<a class="anchor" id="table"></a>
#
# * [1 Data Loading, Cleaning, Labelling, and Exploration](#1)
#     * [1.1 Data Loading](#1.1)
#         * [1.1.1 Create Spark Session](#1.1.1)
#         * [1.1.2 Load CSV files & display total number of rows](#1.1.2)
#         * [1.1.3 Obtain column list](#1.1.3)
#
#     * [1.2 Data Cleaning](#1.2)
#         * [1.2.1 Check for missing values in columns](#1.2.1)
#         * [1.2.2.a Remove selected columns](#1.2.2.a)
#         * [1.2.2.b Drop rows with Null & NaN values](#1.2.2.b)
#
#     * [1.3 Data Labelling](#1.3)
#         * [1.3.1 Add label columns for binary classification](#1.3.1)
#         * [1.3.2 Add label columns for multiclass classification](#1.3.2)
#
#     * [1.4 Data Exploration](#1.4)
#         * [1.4.1 Show statistics of numeric columns](#1.4.1)
#         * [1.4.2 Show number of records in each class (binary and multiclass)](#1.4.2)
#
# * [2 Feature extraction and ML Training](#2)
#     * [2.1 Prepare the feature columns](#2.1)
#         * [2.1.1 Add additional feature column "DEPT_TIME_FLAG"](#2.1.1)
#         * [2.1.2 Select relevant columns (both feature & label columns)](#2.1.2)
#     * [2.2 Preparing any Spark ML Transformers/ Estimators for features and models](#2.2)
#         * [2.2.1 Create Transformers/Estimators for feature columns](#2.2.1)
#         * [2.2.2 Create ML model Estimators for DT & Gradient Boosted tree for binary classification](#2.2.2)
#         * [2.2.3 Create ML model Estimators for Naïve Bayes for multi-class classification](#2.2.3)
#         * [2.2.4 Create Pipeline Model](#2.2.4)
#
#     * [2.3 Preparing the training and testing data](#2.3)
#     * [2.4 Training and evaluating models](#2.4)
#         * [2.4.1 Binary classification tasks](#2.4.1)
#         * [2.4.2 Multiclass Classification tasks](#2.4.2)

# %% [markdown]
# # 1 Data Loading, Cleaning, Labelling, and Exploration<a class="anchor" id="1"></a>
# In this section, you will prepare the data (loading and cleaning) and performing data exploration.
#
# ## 1.1 Data Loading<a class="anchor" id="1.1"></a>
# [Back to top](#table)

# %% [markdown]
# ### 1.1.1 Create Spark Session <a class="anchor" id="1.1.1"></a>
# [Back to top](#table)

# %% [markdown]
# Write the code to get an object using SparkSession, which tells Spark how to access a cluster. To create a SparkSession you first need to build a SparkConf object that contains information about your application. Give an appropriate name for your application and run Spark locally with as many working processors as logical cores on your machine.

# %%
from pyspark import SparkConf
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
# Import SparkContext 
from pyspark import SparkContext # Spark

# local[*]: run Spark in local mode with as many working processors as logical cores on your machine
master = "local[*]"
# Giving the app name of Assignment 2 to be shown on the Spark cluster UI page
app_name = "Assignment 2"
# Setup configuration parameters for Spark
spark_conf = SparkConf().setMaster(master).setAppName(app_name)

# Method 1: Using SparkSession
spark = SparkSession.builder.config(conf=spark_conf).getOrCreate()
sc = spark.sparkContext
sc.setLogLevel('ERROR')

# %% [markdown]
# ### 1.1.2 Load CSV files & display total number of rows <a class="anchor" id="1.1.2"></a>
# [Back to top](#table)

# %% [markdown]
# Read the 20 files of “flight*.csv” file into a single Spark DataFrame namely flightsRawDf using spark.read.csv with both header and inferSchema attributes are set to True. Display the total number of flightsRawDf rows.

# %%
#reading the files into flightsRawDf
flightsRawDf = spark.read.csv("flight*.csv", header = True, inferSchema = True)
#displaying the total number of rows
print("The total number of rows is " + str(flightsRawDf.count()))
# Out:
# The total number of rows is 582184

# %% [markdown]
# ### 1.1.3 Obtain column list  <a class="anchor" id="1.1.3"></a>
# [Back to top](#table)

# %% [markdown]
# Obtain the list of columns from flightsRawDf and name this variable as allColumnFlights.

# %%
# get a list of columns
allColumnFlights = [ x for x in flightsRawDf.columns]
print(allColumnFlights) # to be removed
# Out:
# ['YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'FLIGHT_NUMBER', 'TAIL_NUMBER', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT', 'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY', 'TAXI_OUT', 'WHEELS_OFF', 'SCHEDULED_TIME', 'ELAPSED_TIME', 'AIR_TIME', 'DISTANCE', 'WHEELS_ON', 'TAXI_IN', 'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME', 'ARRIVAL_DELAY', 'DIVERTED', 'CANCELLED', 'CANCELLATION_REASON', 'AIR_SYSTEM_DELAY', 'SECURITY_DELAY', 'AIRLINE_DELAY', 'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY']

# %% [markdown]
# ## 1.2 Data Cleaning<a class="anchor" id="1.2"></a>

# %% [markdown]
# ### 1.2.1 Check for missing values in columns <a class="anchor" id="1.2.1"></a>
# [Back to top](#table)

# %% [markdown]
# Check for missing values (NaN and Null) in all columns, display the number of missing values for each column. Since there are many columns in the data, it is best to visualize the number of null values for a selected set of columns at one snap shot.

# %%
from pyspark.sql.functions import isnan, when, count, col
flightsRawDf.select([count(when(isnan(c) | col(c).isNull(), c)).alias(c) for c in flightsRawDf.columns]).show()
# Out:
# +----+-----+---+-----------+-------+-------------+-----------+--------------+-------------------+-------------------+--------------+---------------+--------+----------+--------------+------------+--------+--------+---------+-------+-----------------+------------+-------------+--------+---------+-------------------+----------------+--------------+-------------+-------------------+-------------+
# |YEAR|MONTH|DAY|DAY_OF_WEEK|AIRLINE|FLIGHT_NUMBER|TAIL_NUMBER|ORIGIN_AIRPORT|DESTINATION_AIRPORT|SCHEDULED_DEPARTURE|DEPARTURE_TIME|DEPARTURE_DELAY|TAXI_OUT|WHEELS_OFF|SCHEDULED_TIME|ELAPSED_TIME|AIR_TIME|DISTANCE|WHEELS_ON|TAXI_IN|SCHEDULED_ARRIVAL|ARRIVAL_TIME|ARRIVAL_DELAY|DIVERTED|CANCELLED|CANCELLATION_REASON|AIR_SYSTEM_DELAY|SECURITY_DELAY|AIRLINE_DELAY|LATE_AIRCRAFT_DELAY|WEATHER_DELAY|
# +----+-----+---+-----------+-------+-------------+-----------+--------------+-------------------+-------------------+--------------+---------------+--------+----------+--------------+------------+--------+--------+---------+-------+-----------------+------------+-------------+--------+---------+-------------------+----------------+--------------+-------------+-------------------+-------------+
# |   0|    0|  0|          0|      0|            0|       1462|             0|                  0|                  0|          8633|           8633|    8891|      8891|             1|       10455|   10455|       0|     9257|   9257|                0|        9257|        10455|       0|        0|             573213|          475831|        475831|       475831|             475831|       475831|
# +----+-----+---+-----------+-------+-------------+-----------+--------------+-------------------+-------------------+--------------+---------------+--------+----------+--------------+------------+--------+--------+---------+-------+-----------------+------------+-------------+--------+---------+-------------------+----------------+--------------+-------------+-------------------+-------------+

# %% [markdown]
# ### 1.2.2.a Remove selected columns <a class="anchor" id="1.2.2.a"></a>
# [Back to top](#table)

# %% [markdown]
# Remove these column list ['CANCELLATION_REASON', 'AIR_SYSTEM_DELAY', 'SECURITY_DELAY', 'AIRLINE_DELAY', 'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY'] from the flightsRawDf . These columns have high number of missing values. Then, display the number of retained columns in flightsRawDf.

# %%
#list down the columns to be removed
columnsToDrop = ['CANCELLATION_REASON', 'AIR_SYSTEM_DELAY', 'SECURITY_DELAY', 'AIRLINE_DELAY', 'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY'] 
#dropping the columns from the list
flightsRawDf = flightsRawDf.drop(*columnsToDrop)
#display the number of retained columns
print("The number of retained columns is " + str(len(flightsRawDf.columns)))
# Out:
# The number of retained columns is 25

# %% [markdown]
# ### 1.2.2.b Drop rows with Null & NaN values <a class="anchor" id="1.2.2.b"></a>
# [Back to top](#table)

# %% [markdown]
# Drop rows with Null and Nan values from resulting flightsRawDf. Please name it as flightsDf. Display the number of rows (or number of records) in flightsDf.

# %%
flightsDf=flightsRawDf.na.drop()
print("The number of rows after dropping is " + str(flightsDf.count()))
# Out:
# The number of rows after dropping is 571729

# %% [markdown]
# ## 1.3 Data Labelling<a class="anchor" id="1.3"></a>

# %% [markdown]
# ### 1.3.1 Add label columns for binary classification <a class="anchor" id="1.3.1"></a>
# [Back to top](#table)

# %% [markdown]
# The new binary labels generated from arrival delay and departure delay columns for the binary classification task purpose. The new column names are binaryArrDelay and binaryDeptDelay, which are generated from arrival delay and departure delay respectively. Label the data as 1 (late) if the delay value is positive, otherwise label it as 0 (not late).

# %%
import pyspark.sql.functions as F
# for arrival delay
flightsDf = flightsDf.withColumn("binaryArrDelay", F.when(F.col("ARRIVAL_DELAY") > 0, 1).otherwise(0))
# for departure delay
flightsDf = flightsDf.withColumn("binaryDeptDelay", F.when(F.col("DEPARTURE_DELAY") > 0, 1).otherwise(0))

# %% [markdown]
# ### 1.3.2 Add label columns for multiclass classification <a class="anchor" id="1.3.2"></a>
# [Back to top](#table)

# %% [markdown]
# The new multiclass labels generated from arrival delay and departure delay columns for the multiclass classification task purpose. The new column names are multiClassArrDelay and multiClassDeptDelay, which are generated from arrival delay and departure delay values respectively. For multiclass labels. Please make it three classes as early, on time, and late which are represented by the labels 0, 1, and 2, respectively. The values below 5 are regarded as early, 5 to 20 are regarded as on time, and above 20 are regarded as late.

# %%
# for arrival delay
flightsDf = flightsDf.withColumn('multiClassArrDelay', F.when(F.col('ARRIVAL_DELAY') < 5, 0).when((F.col('ARRIVAL_DELAY') >= 5) & (F.col('ARRIVAL_DELAY') <= 20), 1).otherwise(2))
# for departure delay
flightsDf = flightsDf.withColumn('multiClassDeptDelay', F.when(F.col('DEPARTURE_DELAY') < 5, 0).when((F.col('DEPARTURE_DELAY') >= 5) & (F.col('DEPARTURE_DELAY') <= 20), 1).otherwise(2))

# %% [markdown]
# ## 1.4 Data Exploration <a class="anchor" id="1.4"></a>

# %% [markdown]
# ### 1.4.1 Show statistics of numeric columns<a class="anchor" id="1.4.1"></a>
# [Back to top](#table)

# %% [markdown]
# Show the basic statistics (count, mean, stddev, min, max, 25 and 75 percentile) for all numerical columns (integer-type data) of the flightsDf, except for the class label columns: binaryArrDelay, binaryDeptDelay, multiClassArrDelay and multiClassDeptDelay.

# %%
# choosing only the int type columns and excluding the class label columns
flightsDf.select([c for c in flightsDf.columns if (dict(flightsDf.dtypes)[c] == "int") & (c not in {'binaryArrDelay', 'binaryDeptDelay', 'multiClassArrDelay', 'multiClassDeptDelay'})]).summary("count","mean","stddev", "min", "25%", "75%", "max").show()
# Out:
# +-------+------+------------------+------------------+------------------+------------------+-------------------+------------------+-----------------+-----------------+------------------+------------------+-----------------+------------------+-----------------+------------------+-----------------+------------------+------------------+-----------------+--------+---------+
# |summary|  YEAR|             MONTH|               DAY|       DAY_OF_WEEK|     FLIGHT_NUMBER|SCHEDULED_DEPARTURE|    DEPARTURE_TIME|  DEPARTURE_DELAY|         TAXI_OUT|        WHEELS_OFF|    SCHEDULED_TIME|     ELAPSED_TIME|          AIR_TIME|         DISTANCE|         WHEELS_ON|          TAXI_IN| SCHEDULED_ARRIVAL|      ARRIVAL_TIME|    ARRIVAL_DELAY|DIVERTED|CANCELLED|
# +-------+------+------------------+------------------+------------------+------------------+-------------------+------------------+-----------------+-----------------+------------------+------------------+-----------------+------------------+-----------------+------------------+-----------------+------------------+------------------+-----------------+--------+---------+
# |  count|571729|            571729|            571729|            571729|            571729|             571729|            571729|           571729|           571729|            571729|            571729|           571729|            571729|           571729|            571729|           571729|            571729|            571729|           571729|  571729|   571729|
# |   mean|2015.0| 6.542260406591235|15.711267051347754|3.9328580498802754|2160.6212803618496|  1328.704886405972|1334.7145098464482|9.323501169260261|16.07680911760642|1357.0151068075959|141.88530230231456|137.0288860631523|113.51732726519033|824.2981115178695|1472.2605605103117|7.434749680355553|1494.0105504530993|1477.3479043392936|4.467084930098001|     0.0|      0.0|
# | stddev|   0.0|3.3989080609437297| 8.768837723805682|1.9840872105208625|1752.1910605700507| 483.32212195085305| 496.1526432015719|37.43009496287022|8.921954000991107| 497.6971682890493| 75.20401414950909|74.12748209604348| 72.12270460026947|607.4673114180731| 521.2022261737656|5.606216411424567|506.25749794034306|  525.302163929245|39.78708619085888|     0.0|      0.0|
# |    min|  2015|                 1|                 1|                 1|                 1|                  1|                 1|              -48|                1|                 1|                18|               14|                 7|               31|                 1|                1|                 1|                 1|              -82|       0|        0|
# |    25%|  2015|                 4|                 8|                 2|               727|                917|               921|               -5|               11|               935|                86|               82|                60|              373|              1055|                4|              1110|              1059|              -13|       0|        0|
# |    75%|  2015|                 9|                23|                 6|              3202|               1730|              1740|                7|               19|              1754|               174|              169|               144|             1065|              1912|                9|              1918|              1917|                8|       0|        0|
# |    max|  2015|                12|                31|                 7|              7438|               2359|              2400|             1670|              200|              2400|               683|              726|               684|             4983|              2400|              202|              2400|              2400|             1665|       0|        0|
# +-------+------+------------------+------------------+------------------+------------------+-------------------+------------------+-----------------+-----------------+------------------+------------------+-----------------+------------------+-----------------+------------------+-----------------+------------------+------------------+-----------------+--------+---------+

# %% [markdown]
# ### 1.4.2 Show number of records in each class (binary and multiclass)<a class="anchor" id="1.4.2"></a>
# [Back to top](#table)

# %% [markdown]
# Write code to count and show number of records in each class for the binary classification (i.e., class labels 0 and 1) and the multiclass classification (i.e., class labels 0, 1, 2) based on the columns binaryArrDelay, binaryDeptDelay, multiClassArrDelay and multiClassDeptDelay. Do you see any class imbalance? Describe what you observe and discuss how it could impact classification.

# %%
# count the number of records in binaryArrDelay
flightsDf.groupBy('binaryArrDelay').count().show()

# count the number of records in binaryDeptDelay
flightsDf.groupBy('binaryDeptDelay').count().show()

# count the number of records in multiClassArrDelay
flightsDf.groupBy('multiClassArrDelay').count().show()

# count the number of records in multiClassDeptDelay
flightsDf.groupBy('multiClassDeptDelay').count().show()
# Out:
# +--------------+------+
# |binaryArrDelay| count|
# +--------------+------+
# |             1|209055|
# |             0|362674|
# +--------------+------+
#
# +---------------+------+
# |binaryDeptDelay| count|
# +---------------+------+
# |              1|211228|
# |              0|360501|
# +---------------+------+
#
# +------------------+------+
# |multiClassArrDelay| count|
# +------------------+------+
# |                 1| 82428|
# |                 2| 85692|
# |                 0|403609|
# +------------------+------+
#
# +-------------------+------+
# |multiClassDeptDelay| count|
# +-------------------+------+
# |                  1| 78843|
# |                  2| 84831|
# |                  0|408055|
# +-------------------+------+

# %% [markdown]
# In the binary classification, it could be observed that the number of records for label 0 (+-360000) is higher than that for label 1 (+-210000), which is a difference of approximately 1.7. As for the multiclass classification, while number of records for lables 1 and 2 are relatively the same, the number of record for label 0 is almost 5 times larger, which creates a significant class imbalance.
# Obviously, the impact of the class imbalance is negative, since it leads to the machine learning models over-classify the larger classes, which is 0 for both binary and multiclass classification, because of their increaed prior probability. Thus, since the machine learning classifier is more biased towards the majority class, the instances of the smaller classes are missclassifies.

# %% [markdown]
# # 2 Feature extraction and ML Training <a class="anchor" id="2"></a>
# In this section, you will need to use PySpark DataFrame functions and ML packages for data preparation, model building and evaluation. Other ML packages such as scikit learn would receive zero marks. Excessive usage of Spark SQL is discouraged.
#
# ## 2.1 Prepare the feature columns <a class="anchor" id="2.1"></a>
# ### 2.1.1 Add additional feature column "DEPT_TIME_FLAG"<a class="anchor" id="2.1.1"></a>
# [Back to top](#table)

# %% [markdown]
# Write code to prepare an additional feature column called “DEPT_TIME_FLAG” (in string type), by mapping the values in the column “SCHEDULED_DEPARTURE” (in integer-type) to one of the five categories in DEPT_TIME_FLAG, according to the following ranges:
#
# SCHEDULED_DEPARTURE DEPT_TIME_FLAG
#     * 0000 - 0500 Midnight
#     * 0500 - 1100 Morning
#     * 1100 - 1600 Afternoon
#     * 1600 - 2000 Evening
#     * 2000 - 2359 Night

# %%
#mapping the values
flightsDf = flightsDf.withColumn('DEPT_TIME_FLAG', F.when((F.col('SCHEDULED_DEPARTURE') >= 0) & (F.col('SCHEDULED_DEPARTURE') < 500), "Midnight")
                                 .when((F.col('SCHEDULED_DEPARTURE') >= 500) & (F.col('SCHEDULED_DEPARTURE') < 1100), "Morning")
                                 .when((F.col('SCHEDULED_DEPARTURE') >= 1100) & (F.col('SCHEDULED_DEPARTURE') < 1600), "Afternoon")
                                 .when((F.col('SCHEDULED_DEPARTURE') >= 1600) & (F.col('SCHEDULED_DEPARTURE') < 2000), "Evening")
                                 .when((F.col('SCHEDULED_DEPARTURE') >= 2000) & (F.col('SCHEDULED_DEPARTURE') <= 2359), "Night")
                                 .otherwise("Invalid value"))
#showing the result
flightsDf.show()
# Out:
# +----+-----+---+-----------+-------+-------------+-----------+--------------+-------------------+-------------------+--------------+---------------+--------+----------+--------------+------------+--------+--------+---------+-------+-----------------+------------+-------------+--------+---------+--------------+---------------+------------------+-------------------+--------------+
# |YEAR|MONTH|DAY|DAY_OF_WEEK|AIRLINE|FLIGHT_NUMBER|TAIL_NUMBER|ORIGIN_AIRPORT|DESTINATION_AIRPORT|SCHEDULED_DEPARTURE|DEPARTURE_TIME|DEPARTURE_DELAY|TAXI_OUT|WHEELS_OFF|SCHEDULED_TIME|ELAPSED_TIME|AIR_TIME|DISTANCE|WHEELS_ON|TAXI_IN|SCHEDULED_ARRIVAL|ARRIVAL_TIME|ARRIVAL_DELAY|DIVERTED|CANCELLED|binaryArrDelay|binaryDeptDelay|multiClassArrDelay|multiClassDeptDelay|DEPT_TIME_FLAG|
# +----+-----+---+-----------+-------+-------------+-----------+--------------+-------------------+-------------------+--------------+---------------+--------+----------+--------------+------------+--------+--------+---------+-------+-----------------+------------+-------------+--------+---------+--------------+---------------+------------------+-------------------+--------------+
# |2015|    6| 26|          5|     EV|         4951|     N707EV|           BHM|                LGA|                630|           629|             -1|      13|       642|           155|         141|     113|     866|      935|     15|             1005|         950|          -15|       0|        0|             0|              0|                 0|                  0|       Morning|
# |2015|   12| 19|          6|     WN|         3589|     N764SW|           MKE|                DCA|               1630|          1627|             -3|      13|      1640|           115|          96|      79|     634|     1859|      4|             1925|        1903|          -22|       0|        0|             0|              0|                 0|                  0|       Evening|
# |2015|    1| 10|          6|     WN|         3370|     N720WN|           SNA|                OAK|               1055|          1054|             -1|      11|      1105|            85|          80|      63|     371|     1208|      6|             1220|        1214|           -6|       0|        0|             0|              0|                 0|                  0|       Morning|
# |2015|   11|  1|          7|     WN|         2081|     N461WN|           PDX|                LAS|               1345|          1346|              1|       9|      1355|           120|         115|      97|     763|     1532|      9|             1545|        1541|           -4|       0|        0|             0|              1|                 0|                  0|     Afternoon|
# |2015|    6| 11|          4|     WN|          836|     N8628A|           BNA|                BOS|               1635|          1627|             -8|      12|      1639|           150|         149|     127|     942|     1946|     10|             2005|        1956|           -9|       0|        0|             0|              0|                 0|                  0|       Evening|
# |2015|    6| 23|          2|     OO|         4620|     N602XJ|           BUR|                SLC|               1629|          1626|             -3|      10|      1636|           108|         108|      86|     574|     1902|     12|             1917|        1914|           -3|       0|        0|             0|              0|                 0|                  0|       Evening|
# |2015|    6|  4|          4|     DL|           55|     N368NB|           ATL|                IAH|                920|           914|             -6|      17|       931|           121|         113|      94|     689|     1005|      2|             1021|        1007|          -14|       0|        0|             0|              0|                 0|                  0|       Morning|
# |2015|    1| 19|          1|     EV|         5553|     N840AS|           CID|                DTW|               1633|          1624|             -9|      13|      1637|            92|          91|      73|     430|     1850|      5|             1905|        1855|          -10|       0|        0|             0|              0|                 0|                  0|       Evening|
# |2015|   12|  1|          2|     WN|         1071|     N7708E|           HOU|                PHX|                555|           611|             16|       7|       618|           175|         169|     157|    1020|      755|      5|              750|         800|           10|       0|        0|             1|              1|                 1|                  1|       Morning|
# |2015|    4|  8|          3|     WN|         1170|     N408WN|           MDW|                PHL|               1700|          1725|             25|      32|      1757|           120|         135|      94|     668|     2031|      9|             2000|        2040|           40|       0|        0|             1|              1|                 2|                  2|       Evening|
# |2015|   12|  1|          2|     WN|         2125|     N7823A|           BUR|                OAK|               1425|          1421|             -4|      13|      1434|            70|          70|      51|     325|     1525|      6|             1535|        1531|           -4|       0|        0|             0|              0|                 0|                  0|     Afternoon|
# |2015|    8| 24|          1|     B6|          724|     N247JB|           MCO|                DCA|               1114|          1113|             -1|      10|      1123|           129|         120|     105|     759|     1308|      5|             1323|        1313|          -10|       0|        0|             0|              0|                 0|                  0|     Afternoon|
# |2015|    7|  3|          5|     AA|         1644|     N3LDAA|           ORD|                SNA|               1200|          1159|             -1|      16|      1215|           264|         242|     219|    1726|     1354|      7|             1424|        1401|          -23|       0|        0|             0|              0|                 0|                  0|     Afternoon|
# |2015|   10| 15|          4|     WN|         1457|     N8630B|         11292|              14747|                830|           846|             16|      10|       856|           175|         157|     141|    1024|     1017|      6|             1025|        1023|           -2|       0|        0|             0|              1|                 0|                  1|       Morning|
# |2015|    3|  3|          2|     WN|          416|     N915WN|           DAY|                DEN|               1640|          1712|             32|       8|      1720|           190|         218|     202|    1085|     1842|      8|             1750|        1850|           60|       0|        0|             1|              1|                 2|                  2|       Evening|
# |2015|    5|  8|          5|     US|          853|     N742PS|           CLT|                BUF|               1630|          1624|             -6|      24|      1648|           105|         105|      78|     546|     1806|      3|             1815|        1809|           -6|       0|        0|             0|              0|                 0|                  0|       Evening|
# |2015|    6| 14|          7|     WN|         4543|     N8618N|           PHX|                HOU|               1015|          1014|             -1|      14|      1028|           160|         159|     140|    1020|     1448|      5|             1455|        1453|           -2|       0|        0|             0|              0|                 0|                  0|       Morning|
# |2015|    5| 17|          7|     OO|         4972|     N772SK|           IAH|                MIA|               1040|          1055|             15|      57|      1152|           140|         197|     132|     964|     1504|      8|             1400|        1512|           72|       0|        0|             1|              1|                 2|                  1|       Morning|
# |2015|    5| 16|          6|     WN|         3036|     N442WN|           ELP|                PHX|                950|           950|              0|      10|      1000|            80|          79|      63|     347|     1003|      6|             1010|        1009|           -1|       0|        0|             0|              0|                 0|                  0|       Morning|
# |2015|    9| 24|          4|     EV|         4654|     N11526|           IAH|                HRL|               1143|          1132|            -11|      15|      1147|            73|          67|      48|     295|     1235|      4|             1256|        1239|          -17|       0|        0|             0|              0|                 0|                  0|     Afternoon|
# +----+-----+---+-----------+-------+-------------+-----------+--------------+-------------------+-------------------+--------------+---------------+--------+----------+--------------+------------+--------+--------+---------+-------+-----------------+------------+-------------+--------+---------+--------------+---------------+------------------+-------------------+--------------+
# only showing top 20 rows

# %% [markdown]
# ### 2.1.2 Select relevant columns (both feature & label columns)<a class="anchor" id="2.1.2"></a>
# [Back to top](#table)

# %% [markdown]
# Write the code to create a new dataframe consisting of relevant columns, and name it as ‘flightsDf_data’. The relevant columns are given as follows: 'MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'DEPT_TIME_FLAG', 'ELAPSED_TIME','DISTANCE', 'TAXI_IN', 'TAXI_OUT', 'AIR_TIME', 'SCHEDULED_TIME', 'binaryArrDelay', 'binaryDeptDelay', 'multiClassDeptDelay', 'multiClassArrDelay'.

# %%
# select the columns and place them into the new DF
flightsDf_data = flightsDf.select('MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'DEPT_TIME_FLAG', 'ELAPSED_TIME','DISTANCE', 'TAXI_IN', 'TAXI_OUT', 'AIR_TIME', 'SCHEDULED_TIME', 'binaryArrDelay', 'binaryDeptDelay', 'multiClassDeptDelay', 'multiClassArrDelay')
# showing the result
flightsDf_data.show()
# Out:
# +-----+---+-----------+-------+--------------+------------+--------+-------+--------+--------+--------------+--------------+---------------+-------------------+------------------+
# |MONTH|DAY|DAY_OF_WEEK|AIRLINE|DEPT_TIME_FLAG|ELAPSED_TIME|DISTANCE|TAXI_IN|TAXI_OUT|AIR_TIME|SCHEDULED_TIME|binaryArrDelay|binaryDeptDelay|multiClassDeptDelay|multiClassArrDelay|
# +-----+---+-----------+-------+--------------+------------+--------+-------+--------+--------+--------------+--------------+---------------+-------------------+------------------+
# |    6| 26|          5|     EV|       Morning|         141|     866|     15|      13|     113|           155|             0|              0|                  0|                 0|
# |   12| 19|          6|     WN|       Evening|          96|     634|      4|      13|      79|           115|             0|              0|                  0|                 0|
# |    1| 10|          6|     WN|       Morning|          80|     371|      6|      11|      63|            85|             0|              0|                  0|                 0|
# |   11|  1|          7|     WN|     Afternoon|         115|     763|      9|       9|      97|           120|             0|              1|                  0|                 0|
# |    6| 11|          4|     WN|       Evening|         149|     942|     10|      12|     127|           150|             0|              0|                  0|                 0|
# |    6| 23|          2|     OO|       Evening|         108|     574|     12|      10|      86|           108|             0|              0|                  0|                 0|
# |    6|  4|          4|     DL|       Morning|         113|     689|      2|      17|      94|           121|             0|              0|                  0|                 0|
# |    1| 19|          1|     EV|       Evening|          91|     430|      5|      13|      73|            92|             0|              0|                  0|                 0|
# |   12|  1|          2|     WN|       Morning|         169|    1020|      5|       7|     157|           175|             1|              1|                  1|                 1|
# |    4|  8|          3|     WN|       Evening|         135|     668|      9|      32|      94|           120|             1|              1|                  2|                 2|
# |   12|  1|          2|     WN|     Afternoon|          70|     325|      6|      13|      51|            70|             0|              0|                  0|                 0|
# |    8| 24|          1|     B6|     Afternoon|         120|     759|      5|      10|     105|           129|             0|              0|                  0|                 0|
# |    7|  3|          5|     AA|     Afternoon|         242|    1726|      7|      16|     219|           264|             0|              0|                  0|                 0|
# |   10| 15|          4|     WN|       Morning|         157|    1024|      6|      10|     141|           175|             0|              1|                  1|                 0|
# |    3|  3|          2|     WN|       Evening|         218|    1085|      8|       8|     202|           190|             1|              1|                  2|                 2|
# |    5|  8|          5|     US|       Evening|         105|     546|      3|      24|      78|           105|             0|              0|                  0|                 0|
# |    6| 14|          7|     WN|       Morning|         159|    1020|      5|      14|     140|           160|             0|              0|                  0|                 0|
# |    5| 17|          7|     OO|       Morning|         197|     964|      8|      57|     132|           140|             1|              1|                  1|                 2|
# |    5| 16|          6|     WN|       Morning|          79|     347|      6|      10|      63|            80|             0|              0|                  0|                 0|
# |    9| 24|          4|     EV|     Afternoon|          67|     295|      4|      15|      48|            73|             0|              0|                  0|                 0|
# +-----+---+-----------+-------+--------------+------------+--------+-------+--------+--------+--------------+--------------+---------------+-------------------+------------------+
# only showing top 20 rows

# %% [markdown]
# ## 2.2. Preparing any Spark ML Transformers/ Estimators for features and models<a class="anchor" id="2.2"></a>
# ### 2.2.1 Create Transformers/Estimators for feature columns <a class="anchor" id="2.2.1"></a>
# [Back to top](#table)

# %% [markdown]
# Write code to create Transformers/Estimators for transforming/assembling the columns selected above in 2.1.2.

# %%
from pyspark.ml.feature import StringIndexer
from pyspark.ml.linalg import Vectors
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.feature import OneHotEncoder

# the categorical columns 
catCols = ['MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'DEPT_TIME_FLAG']
# the numerical columns
intCols = [ 'ELAPSED_TIME','DISTANCE', 'TAXI_IN','TAXI_OUT', 'AIR_TIME', 'SCHEDULED_TIME']

# label columns to exclude 
labelCols = ['binaryArrDelay', 'binaryDeptDelay', 'multiClassDeptDelay', 'multiClassArrDelay']
# get all the input columns 
inputCols = [x for x in flightsDf_data.columns if x not in labelCols] 


# 1. Indexer only for categorical:
outputCols_index=[f'{x}_index' for x in catCols] # defining the output columns
indexer = StringIndexer(inputCols=catCols, outputCols=outputCols_index) #initializing the string indexer
indexer = indexer.setHandleInvalid("skip")

# 2.1 Encoder only for categorical:
outputCols_enc=[f'{x}_vec' for x in catCols] # defining the output columns
encoder = OneHotEncoder(inputCols=outputCols_index, outputCols=outputCols_enc) # initializing the encoder

# make the input for assembler both categorical and numerical
inputColsAssembler = outputCols_enc + intCols

# 3. Assembler:
assembler = VectorAssembler(inputCols= inputColsAssembler, outputCol="features")

# %% [markdown]
# ### 2.2.2 Create ML model Estimators for DT & Gradient Boosted tree for binary classification<a class="anchor" id="2.2.2"></a>
# [Back to top](#table)

# %% [markdown]
# Create ML model Estimators for Decision Tree and Gradient Boosted Tree model for binary classification for both arrival and departure delays from the labels that you have created at task 1.3.1 (a) (PLEASE DO NOT fit/transform the data yet).

# %%
from pyspark.ml.classification import DecisionTreeClassifier
from pyspark.ml.classification import GBTClassifier

# binary arrival delay
dt_arrival = DecisionTreeClassifier(featuresCol = 'features', labelCol = 'binaryArrDelay') # Decision Tree 
gbt_arrival = GBTClassifier(featuresCol="features",labelCol="binaryArrDelay") # Gradient Boosted Tree 

#binary departure delay
dt_departure = DecisionTreeClassifier(featuresCol = 'features', labelCol = 'binaryDeptDelay') # Decision Tree 
gbt_departure = GBTClassifier(featuresCol="features",labelCol="binaryDeptDelay") # Gradient Boosted Tree

# %% [markdown]
# ### 2.2.3 Create ML model Estimators for Naïve Bayes for multi-class classification<a class="anchor" id="2.2.3"></a>
# [Back to top](#table)

# %% [markdown]
# Create ML model Estimators for Naive Bayes model for multiclass classification for only arrival delay from the labels that you have created at task 1.3.1 (b) (PLEASE DO NOT fit/transform the data yet).

# %%
from pyspark.ml.classification import NaiveBayes

# creating the naive bayes model for arrival delay only
nb_arrival = NaiveBayes(labelCol= "multiClassArrDelay", featuresCol ='features', smoothing=1.0, modelType="multinomial")

# %% [markdown]
# ### 2.2.4 Create pipeline model <a class="anchor" id="2.2.4"></a>
# [Back to top](#table)

# %% [markdown]
# Write code to include the above Transformers/Estimators into pipelines for all tasks (PLEASE DO NOT fit/transform the data yet).

# %%
from pyspark.ml import Pipeline

#getting the stages from 2.2.1
stage_1 = indexer
stage_2 = encoder
stage_3 = assembler


#Pipeline for binary arrival delay Decision Tree
stage_4 = dt_arrival
pipeline_dt_arr = Pipeline(stages=[stage_1,stage_2,stage_3, stage_4 ])

#Pipeline for binary arrival delay Gradient Boosted Tree 
stage_4 = gbt_arrival
pipeline_gbt_arr = Pipeline(stages=[stage_1,stage_2,stage_3, stage_4 ])

#Pipeline for binary departure delay Decision Tree
stage_4 = dt_departure
pipeline_dt_dept = Pipeline(stages=[stage_1,stage_2,stage_3, stage_4 ])

#Pipeline for binary departure delay Gradient Boosted Tree 
stage_4 = gbt_departure
pipeline_gbt_dept = Pipeline(stages=[stage_1,stage_2,stage_3, stage_4 ])

#Pipeline for Multiclass Arrival Delay
stage_4 = nb_arrival
pipeline_nb_arr = Pipeline(stages=[stage_1,stage_2,stage_3, stage_4 ])

# %% [markdown]
# ## 2.3. Preparing the training and testing data <a class="anchor" id="2.3"></a>
# Write code to randomly split the data into 80 percent and 20 percent proportion as training and testing data. You may use seed for the analysis purposes. This training and testing data will be used for model evaluation of all tasks in 2.4.
# [Back to top](#table)

# %%
train, test = flightsDf_data.randomSplit([0.2, 0.8], seed = 567) #567 because it is prime

# %% [markdown]
# ## 2.4. Training and evaluating models <a class="anchor" id="2.4"></a>
# For three use cases below, please follow the instructions
#
# [Back to top](#table)

# %% [markdown]
# ### 2.4.1 Binary Classification tasks<a class="anchor" id="2.4.1"></a>
# Binary classification task (Using Decision Tree and Gradient Boosted Tree) for both arrival and departure delay classification (4 models).

# %% [markdown]
# a. Write code to use the corresponding ML Pipelines to train the models on the training data. (Use fit/transform here)

# %%
# For the decision tree arrival
pipelineModel_dt_arr = pipeline_dt_arr.fit(train)
predictions_dt_arr = pipelineModel_dt_arr.transform(test)

# For the Gradient Boosted Tree arrival
pipelineModel_gbt_arr = pipeline_gbt_arr.fit(train)
predictions_gbt_arr = pipelineModel_gbt_arr.transform(test)

# For the decision tree departure
pipelineModel_dt_dept = pipeline_dt_dept.fit(train)
predictions_dt_dept = pipelineModel_dt_dept.transform(test)

# For the Gradient Boosted Tree departure 
pipelineModel_gbt_dept = pipeline_gbt_dept.fit(train)
predictions_gbt_dept = pipelineModel_gbt_dept.transform(test)

# %% [markdown]
# b. For both models and for both delays, write code to display the count of each combination of late/not late label and prediction label in formats as shown in the example Fig.1.

# %%
# For the decision tree arrival
print("Decision tree")
combination_dt_arr = predictions_dt_arr.groupby('binaryArrDelay', 'prediction')
combination_dt_arr = combination_dt_arr.agg(F.count('binaryArrDelay').alias('count'))
combination_dt_arr.withColumnRenamed('binaryArrDelay', 'late (arrival)').show()

# For the decision tree departure
combination_dt_dept = predictions_dt_dept.groupby('binaryDeptDelay', 'prediction')
combination_dt_dept = combination_dt_dept.agg(F.count('binaryDeptDelay').alias('count'))
combination_dt_dept.withColumnRenamed('binaryDeptDelay', 'late (departure)').show()

print("Gradient Boosted Tree")
# For the Gradient Boosted Tree arrival
combination_gbt_arr = predictions_gbt_arr.groupby('binaryArrDelay', 'prediction')
combination_gbt_arr = combination_gbt_arr.agg(F.count('binaryArrDelay').alias('count'))
combination_gbt_arr.withColumnRenamed('binaryArrDelay', 'late (arrival)').show()

# For the Gradient Boosted Tree departure 
combination_gbt_dept = predictions_gbt_dept.groupby('binaryDeptDelay', 'prediction')
combination_gbt_dept = combination_gbt_dept.agg(F.count('binaryDeptDelay').alias('count'))
combination_gbt_dept.withColumnRenamed('binaryDeptDelay', 'late (departure)').show()
# Out:
# Decision tree
# +--------------+----------+------+
# |late (arrival)|prediction| count|
# +--------------+----------+------+
# |             1|       0.0|127707|
# |             0|       0.0|277713|
# |             1|       1.0| 39510|
# |             0|       1.0| 12553|
# +--------------+----------+------+
#
# +----------------+----------+------+
# |late (departure)|prediction| count|
# +----------------+----------+------+
# |               1|       0.0|118030|
# |               0|       0.0|249852|
# |               1|       1.0| 51151|
# |               0|       1.0| 38450|
# +----------------+----------+------+
#
# Gradient Boosted Tree
# +--------------+----------+------+
# |late (arrival)|prediction| count|
# +--------------+----------+------+
# |             1|       0.0|105002|
# |             0|       0.0|270466|
# |             1|       1.0| 62215|
# |             0|       1.0| 19800|
# +--------------+----------+------+
#
# +----------------+----------+------+
# |late (departure)|prediction| count|
# +----------------+----------+------+
# |               1|       0.0|119924|
# |               0|       0.0|254331|
# |               1|       1.0| 49257|
# |               0|       1.0| 33971|
# +----------------+----------+------+

# %% [markdown]
# c. Compute the AUC, accuracy, recall, and precision for the late/not late label from each model testing result using pyspark MLlib/ML APIs.

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

predictions = [predictions_dt_arr, predictions_dt_dept, predictions_gbt_arr, predictions_gbt_dept]
namings = ['Decision tree arrival', 'Decision tree departure', 'Gradient Boosted Tree arrival','Gradient Boosted Tree departure']
labels = ['binaryArrDelay', 'binaryDeptDelay', 'binaryArrDelay', 'binaryDeptDelay']

for i in range(4):
    print(namings[i])
    
    #calculating AUC
    evaluator = BinaryClassificationEvaluator(rawPredictionCol="rawPrediction", labelCol = labels[i] , metricName = 'areaUnderROC')
    auc = evaluator.evaluate(predictions[i])
    print("AUC: "+str(auc))
    
    # calculating accuracy
    evaluator = MulticlassClassificationEvaluator(predictionCol='prediction', labelCol=labels[i], metricName='accuracy')
    accuracy = evaluator.evaluate(predictions[i])
    print("Accuracy: "+str(accuracy))
    
    #calculating precision
    evaluator = MulticlassClassificationEvaluator(predictionCol='prediction', labelCol=labels[i], metricName='precisionByLabel')
    precision = evaluator.evaluate(predictions[i])
    print("Precision: "+str(precision))
    
    #calculating recall
    evaluator = MulticlassClassificationEvaluator(predictionCol='prediction', labelCol=labels[i], metricName='recallByLabel')
    recall = evaluator.evaluate(predictions[i])
    print("Recall: "+str(recall))
    
    print("-----------------------------------------------------------------------------")
# Out:
# Decision tree arrival
# AUC: 0.40015099646318125
# Accuracy: 0.6934093725887082
# Precision: 0.685000739973361
# Recall: 0.9567534606188806
# -----------------------------------------------------------------------------
# Decision tree departure
# AUC: 0.5097257203773058
# Accuracy: 0.6579545032274423
# Precision: 0.6791634274033521
# Recall: 0.8666329057724192
# -----------------------------------------------------------------------------
# Gradient Boosted Tree arrival
# AUC: 0.7556737153275649
# Accuracy: 0.7271986062870096
# Precision: 0.7203436777568262
# Recall: 0.9317867059869224
# -----------------------------------------------------------------------------
# Gradient Boosted Tree departure
# AUC: 0.6664130689791775
# Accuracy: 0.6636049864147957
# Precision: 0.679566071261573
# Recall: 0.8821686981012966
# -----------------------------------------------------------------------------

# %% [markdown]
# d. For each classification task, discuss which is the better model based on performance metric above, and persist the better model. You can name the persisted models as ‘arrival_delay_prediction_model’ and ‘departure_delay_prediction_model’

# %% [markdown]
# Based on the performance metric above, it may be observed that for the arrival delay value, GBT has slightly higher values for accuracy (+-0.727) and precision (+-0.720) than the DT with accuracy of +-0.693 and precision +-0.685; and significantly higher value of AUC, which is +-0.756 for GBT and +-0.400 for DT. However, recall for DT is slightly higher (+-0.956) than that of GBT (+-0.932). Accuracy, precision and AUC are vital, when assesing the model performance, since precision states how many classes are actually positive out of all the correctly predicted positive classes and recall evaluates how many predictions are correct out of all the positive classes , while AUC measurea of the ability of a classifier to distinguish between classes. Thus, it may be concluded that the GBT model is better than the DT model for the arrival delay.
#
# As for the departure delay, all the values of performance metric for GBT are noticeably higher than those for DT, thus for the DT, GBT is is better model.

# %%
arrival_delay_prediction_model = predictions_gbt_arr
departure_delay_prediction_model = predictions_gbt_dept

# %% [markdown]
# e. For each classification task and for each classifier (i.e. Decision Tree and Gradient Boosted Tree), write code to print out the tree structure, and the top-3 features with each corresponding feature importance. Describe the result in a way that it could be understood by your potential users.

# %%
import pandas as pd
# the function below was taken from https://www.timlrx.com/blog/feature-selection-using-feature-importance-score-creating-a-pyspark-estimator
def ExtractFeatureImp(featureImp, dataset, featuresCol):
    list_extract = []
    for i in dataset.schema[featuresCol].metadata["ml_attr"]["attrs"]:
        list_extract = list_extract + dataset.schema[featuresCol].metadata["ml_attr"]["attrs"][i]
    varlist = pd.DataFrame(list_extract)
    varlist['score'] = varlist['idx'].apply(lambda x: featureImp[x])
    return(varlist.sort_values('score', ascending = False))

print("Decision tree arrival")
print("---------------------")
# print out tree for Decision tree arrival
print(pipelineModel_dt_arr.stages[-1].toDebugString)
# for i in range(10):
print(ExtractFeatureImp(pipelineModel_dt_arr.stages[-1].featureImportances, predictions_dt_arr, "features").head(3))
print("-----------------------------------------------------------------------------")

print("Decision tree departure")
print("------------------------")
# print out tree for Decision tree departure
print(pipelineModel_dt_dept.stages[-1].toDebugString)
print(ExtractFeatureImp(pipelineModel_dt_dept.stages[-1].featureImportances, predictions_dt_dept, "features").head(3))
print("-----------------------------------------------------------------------------")

print("Gradient Boosted Tree arrival")
print("------------------------------")
# print out tree for Gradient Boosted Tree arrival
print(pipelineModel_gbt_arr.stages[-1].toDebugString)
print(ExtractFeatureImp(pipelineModel_gbt_arr.stages[-1].featureImportances, predictions_gbt_arr, "features").head(3))
print("-----------------------------------------------------------------------------")

print("Gradient Boosted Tree departure")
print("------------------------------")
# print out tree for Gradient Boosted Tree departure
print(pipelineModel_gbt_dept.stages[-1].toDebugString)
print(ExtractFeatureImp(pipelineModel_gbt_dept.stages[-1].featureImportances, predictions_gbt_dept, "features").head(3))
# Out:
# Decision tree arrival
# ---------------------
# DecisionTreeClassificationModel: uid=DecisionTreeClassifier_f8f6a7bc7e17, depth=5, numNodes=31, numClasses=2, numFeatures=70
#   If (feature 67 <= 25.5)
#    If (feature 66 <= 18.5)
#     Predict: 0.0
#    Else (feature 66 > 18.5)
#     If (feature 66 <= 31.5)
#      If (feature 67 <= 14.5)
#       If (feature 47 in {1.0})
#        Predict: 1.0
#       Else (feature 47 not in {1.0})
#        Predict: 0.0
#      Else (feature 67 > 14.5)
#       Predict: 1.0
#     Else (feature 66 > 31.5)
#      If (feature 69 <= 224.5)
#       Predict: 1.0
#      Else (feature 69 > 224.5)
#       If (feature 68 <= 173.5)
#        Predict: 0.0
#       Else (feature 68 > 173.5)
#        Predict: 1.0
#   Else (feature 67 > 25.5)
#    If (feature 67 <= 33.5)
#     If (feature 69 <= 158.5)
#      If (feature 64 <= 152.5)
#       If (feature 69 <= 139.5)
#        Predict: 1.0
#       Else (feature 69 > 139.5)
#        Predict: 0.0
#      Else (feature 64 > 152.5)
#       Predict: 1.0
#     Else (feature 69 > 158.5)
#      If (feature 64 <= 166.5)
#       Predict: 0.0
#      Else (feature 64 > 166.5)
#       Predict: 1.0
#    Else (feature 67 > 33.5)
#     If (feature 69 <= 146.5)
#      Predict: 1.0
#     Else (feature 69 > 146.5)
#      If (feature 67 <= 49.5)
#       If (feature 64 <= 159.5)
#        Predict: 0.0
#       Else (feature 64 > 159.5)
#        Predict: 1.0
#      Else (feature 67 > 49.5)
#       Predict: 1.0
#
#    idx            name     score
# 3   67        TAXI_OUT  0.749942
# 2   66         TAXI_IN  0.200241
# 5   69  SCHEDULED_TIME  0.024782
# -----------------------------------------------------------------------------
# Decision tree departure
# ------------------------
# DecisionTreeClassificationModel: uid=DecisionTreeClassifier_15237b580859, depth=5, numNodes=41, numClasses=2, numFeatures=70
#   If (feature 60 in {1.0})
#    If (feature 52 in {1.0})
#     If (feature 64 <= 184.5)
#      If (feature 67 <= 17.5)
#       Predict: 0.0
#      Else (feature 67 > 17.5)
#       If (feature 2 in {1.0})
#        Predict: 1.0
#       Else (feature 2 not in {1.0})
#        Predict: 0.0
#     Else (feature 64 > 184.5)
#      If (feature 67 <= 16.5)
#       Predict: 0.0
#      Else (feature 67 > 16.5)
#       Predict: 1.0
#    Else (feature 52 not in {1.0})
#     If (feature 65 <= 1106.0)
#      If (feature 67 <= 24.5)
#       Predict: 0.0
#      Else (feature 67 > 24.5)
#       If (feature 57 in {1.0})
#        Predict: 1.0
#       Else (feature 57 not in {1.0})
#        Predict: 0.0
#     Else (feature 65 > 1106.0)
#      If (feature 7 in {1.0})
#       If (feature 40 in {1.0})
#        Predict: 1.0
#       Else (feature 40 not in {1.0})
#        Predict: 0.0
#      Else (feature 7 not in {1.0})
#       Predict: 0.0
#   Else (feature 60 not in {1.0})
#    If (feature 47 in {1.0})
#     If (feature 8 in {1.0})
#      If (feature 65 <= 1196.0)
#       Predict: 0.0
#      Else (feature 65 > 1196.0)
#       Predict: 1.0
#     Else (feature 8 not in {1.0})
#      Predict: 1.0
#    Else (feature 47 not in {1.0})
#     If (feature 52 in {1.0})
#      If (feature 2 in {1.0})
#       If (feature 28 in {1.0})
#        Predict: 0.0
#       Else (feature 28 not in {1.0})
#        Predict: 1.0
#      Else (feature 2 not in {1.0})
#       If (feature 5 in {1.0})
#        Predict: 0.0
#       Else (feature 5 not in {1.0})
#        Predict: 1.0
#     Else (feature 52 not in {1.0})
#      If (feature 67 <= 26.5)
#       Predict: 0.0
#      Else (feature 67 > 26.5)
#       If (feature 67 <= 49.5)
#        Predict: 0.0
#       Else (feature 67 > 49.5)
#        Predict: 1.0
#
#     idx                        name     score
# 66   60  DEPT_TIME_FLAG_vec_Morning  0.511357
# 53   47              AIRLINE_vec_WN  0.194512
# 58   52              AIRLINE_vec_UA  0.163712
# -----------------------------------------------------------------------------
# Gradient Boosted Tree arrival
# ------------------------------
# GBTClassificationModel: uid = GBTClassifier_8006a4c9e97c, numTrees=20, numClasses=2, numFeatures=70
#   Tree 0 (weight 1.0):
#     If (feature 67 <= 25.5)
#      If (feature 66 <= 18.5)
#       If (feature 60 in {1.0})
#        If (feature 67 <= 17.5)
#         If (feature 67 <= 12.5)
#          Predict: -0.6720675806674976
#         Else (feature 67 > 12.5)
#          Predict: -0.5543096234309624
#        Else (feature 67 > 17.5)
#         If (feature 66 <= 8.5)
#          Predict: -0.3528494716785034
#         Else (feature 66 > 8.5)
#          Predict: -0.1103202846975089
#       Else (feature 60 not in {1.0})
#        If (feature 67 <= 17.5)
#         If (feature 47 in {0.0})
#          Predict: -0.40492632265782175
#         Else (feature 47 not in {0.0})
#          Predict: -0.16512776465535753
#        Else (feature 67 > 17.5)
#         If (feature 48 in {1.0})
#          Predict: -0.3493975903614458
#         Else (feature 48 not in {1.0})
#          Predict: -0.04884905991917062
#      Else (feature 66 > 18.5)
#       If (feature 66 <= 31.5)
#        If (feature 67 <= 14.5)
#         If (feature 47 in {0.0})
#          Predict: -0.020752269779507133
#         Else (feature 47 not in {0.0})
#          Predict: 0.34517766497461927
#        Else (feature 67 > 14.5)
#         If (feature 69 <= 182.5)
#          Predict: 0.521978021978022
#         Else (feature 69 > 182.5)
#          Predict: 0.12264150943396226
#       Else (feature 66 > 31.5)
#        If (feature 69 <= 230.5)
#         If (feature 66 <= 32.5)
#          Predict: 0.5882352941176471
#         Else (feature 66 > 32.5)
#          Predict: 0.8980263157894737
#        Else (feature 69 > 230.5)
#         If (feature 65 <= 1538.0)
#          Predict: -0.07692307692307693
#         Else (feature 65 > 1538.0)
#          Predict: 0.6931818181818182
#     Else (feature 67 > 25.5)
#      If (feature 67 <= 33.5)
#       If (feature 69 <= 158.5)
#        If (feature 64 <= 152.5)
#         If (feature 69 <= 139.5)
#          Predict: 0.3948110547095319
#         Else (feature 69 > 139.5)
#          Predict: -0.09157509157509157
#        Else (feature 64 > 152.5)
#         If (feature 69 <= 145.5)
#          Predict: 1.0
#         Else (feature 69 > 145.5)
#          Predict: 0.7545454545454545
#       Else (feature 69 > 158.5)
#        If (feature 64 <= 167.5)
#         If (feature 64 <= 159.5)
#          Predict: -0.6029411764705882
#         Else (feature 64 > 159.5)
#          Predict: -0.23809523809523808
#        Else (feature 64 > 167.5)
#         If (feature 69 <= 172.5)
#          Predict: 0.6754385964912281
#         Else (feature 69 > 172.5)
#          Predict: 0.14030738720872582
#      Else (feature 67 > 33.5)
#       If (feature 69 <= 145.5)
#        If (feature 67 <= 36.5)
#         If (feature 64 <= 102.5)
#          Predict: 0.6506849315068494
#         Else (feature 64 > 102.5)
#          Predict: 0.8502673796791443
#        Else (feature 67 > 36.5)
#         If (feature 64 <= 140.5)
#          Predict: 0.8842845973416732
#         Else (feature 64 > 140.5)
#          Predict: 0.986863711001642
#       Else (feature 69 > 145.5)
#        If (feature 64 <= 159.5)
#         If (feature 69 <= 151.5)
#          Predict: 0.25
#         Else (feature 69 > 151.5)
#          Predict: -0.3770491803278688
#        Else (feature 64 > 159.5)
#         If (feature 69 <= 164.5)
#          Predict: 0.9678456591639871
#         Else (feature 69 > 164.5)
#          Predict: 0.6004901960784313
#   Tree 1 (weight 0.1):
#     If (feature 66 <= 7.5)
#      If (feature 48 in {1.0})
#       If (feature 67 <= 19.5)
#        If (feature 64 <= 326.5)
#         If (feature 5 in {1.0})
#          Predict: -0.6716427511647289
#         Else (feature 5 not in {1.0})
#          Predict: -0.3686351265807102
#        Else (feature 64 > 326.5)
#         If (feature 69 <= 333.5)
#          Predict: 2.839774426751737
#         Else (feature 69 > 333.5)
#          Predict: 0.14758829044329566
#       Else (feature 67 > 19.5)
#        If (feature 60 in {1.0})
#         If (feature 69 <= 116.5)
#          Predict: 0.024947564764105905
#         Else (feature 69 > 116.5)
#          Predict: -0.5440806899652773
#        Else (feature 60 not in {1.0})
#         If (feature 69 <= 88.5)
#          Predict: 0.3249120156070839
#         Else (feature 69 > 88.5)
#          Predict: -0.02604155626263188
#      Else (feature 48 not in {1.0})
#       If (feature 8 in {1.0})
#        If (feature 59 in {0.0})
#         If (feature 67 <= 27.5)
#          Predict: -0.4056169683268364
#         Else (feature 67 > 27.5)
#          Predict: 0.053799815977777075
#        Else (feature 59 not in {0.0})
#         If (feature 31 in {0.0})
#          Predict: 0.39573086091053555
#         Else (feature 31 not in {0.0})
#          Predict: 2.897020048470799
#       Else (feature 8 not in {1.0})
#        If (feature 5 in {1.0})
#         If (feature 45 in {1.0})
#          Predict: -0.5941473459496011
#         Else (feature 45 not in {1.0})
#          Predict: -0.2460358979463486
#        Else (feature 5 not in {1.0})
#         If (feature 67 <= 13.5)
#          Predict: -0.10241867888770573
#         Else (feature 67 > 13.5)
#          Predict: 0.05145690258515608
#     Else (feature 66 > 7.5)
#      If (feature 48 in {1.0})
#       If (feature 67 <= 18.5)
#        If (feature 66 <= 12.5)
#         If (feature 64 <= 112.5)
#          Predict: -0.4894254753307615
#         Else (feature 64 > 112.5)
#          Predict: -0.2274057814338743
#        Else (feature 66 > 12.5)
#         If (feature 31 in {0.0})
#          Predict: -0.05501359253777006
#         Else (feature 31 not in {0.0})
#          Predict: 0.90889837894457
#       Else (feature 67 > 18.5)
#        If (feature 69 <= 151.5)
#         If (feature 64 <= 80.5)
#          Predict: -0.3182805685734241
#         Else (feature 64 > 80.5)
#          Predict: 0.4035979859269212
#        Else (feature 69 > 151.5)
#         If (feature 64 <= 159.5)
#          Predict: -0.756021927591948
#         Else (feature 64 > 159.5)
#          Predict: -0.01584666891694817
#      Else (feature 48 not in {1.0})
#       If (feature 49 in {1.0})
#        If (feature 67 <= 20.5)
#         If (feature 9 in {0.0})
#          Predict: -0.1590932032790217
#         Else (feature 9 not in {0.0})
#          Predict: 0.31789271285407034
#        Else (feature 67 > 20.5)
#         If (feature 66 <= 17.5)
#          Predict: 0.07105117759471766
#         Else (feature 66 > 17.5)
#          Predict: 0.6212672712017601
#       Else (feature 49 not in {1.0})
#        If (feature 67 <= 12.5)
#         If (feature 59 in {0.0})
#          Predict: 0.054617946671565776
#         Else (feature 59 not in {0.0})
#          Predict: 0.8817584700969692
#        Else (feature 67 > 12.5)
#         If (feature 66 <= 10.5)
#          Predict: 0.2455918472978276
#         Else (feature 66 > 10.5)
#          Predict: 0.4872962544855752
#   Tree 2 (weight 0.1):
#     If (feature 57 in {0.0})
#      If (feature 66 <= 9.5)
#       If (feature 67 <= 21.5)
#        If (feature 48 in {1.0})
#         If (feature 63 in {0.0})
#          Predict: -0.3518161086187383
#         Else (feature 63 not in {0.0})
#          Predict: -0.08918979101497955
#        Else (feature 48 not in {1.0})
#         If (feature 62 in {0.0})
#          Predict: -0.12775593300401705
#         Else (feature 62 not in {0.0})
#          Predict: 0.06212001201902877
#       Else (feature 67 > 21.5)
#        If (feature 69 <= 72.5)
#         If (feature 64 <= 73.5)
#          Predict: 0.11835087526579072
#         Else (feature 64 > 73.5)
#          Predict: 0.9641931788458825
#        Else (feature 69 > 72.5)
#         If (feature 64 <= 84.5)
#          Predict: -0.7094672036343279
#         Else (feature 64 > 84.5)
#          Predict: 0.10625846656473643
#      Else (feature 66 > 9.5)
#       If (feature 67 <= 13.5)
#        If (feature 69 <= 49.5)
#         If (feature 59 in {0.0})
#          Predict: 0.3486570259887868
#         Else (feature 59 not in {0.0})
#          Predict: 1.4548191224324731
#        Else (feature 69 > 49.5)
#         If (feature 8 in {1.0})
#          Predict: -0.3407358058919623
#         Else (feature 8 not in {1.0})
#          Predict: 0.018580006044195897
#       Else (feature 67 > 13.5)
#        If (feature 69 <= 145.5)
#         If (feature 68 <= 104.5)
#          Predict: 0.31906211779957794
#         Else (feature 68 > 104.5)
#          Predict: 1.1076542534578446
#        Else (feature 69 > 145.5)
#         If (feature 68 <= 128.5)
#          Predict: -0.35073271054394534
#         Else (feature 68 > 128.5)
#          Predict: 0.20843124472779256
#     Else (feature 57 not in {0.0})
#      If (feature 2 in {0.0})
#       If (feature 67 <= 11.5)
#        If (feature 36 in {0.0})
#         If (feature 69 <= 333.5)
#          Predict: 0.296784158611915
#         Else (feature 69 > 333.5)
#          Predict: 2.975594842796596
#        Else (feature 36 not in {0.0})
#         If (feature 10 in {1.0})
#          Predict: -1.0274905734004327
#         Else (feature 10 not in {1.0})
#          Predict: 1.8469658394057102
#       Else (feature 67 > 11.5)
#        If (feature 32 in {1.0})
#         If (feature 6 in {0.0})
#          Predict: -0.38192678208607145
#         Else (feature 6 not in {0.0})
#          Predict: 2.2294632118376176
#        Else (feature 32 not in {1.0})
#         If (feature 60 in {1.0})
#          Predict: 0.4967456404842087
#         Else (feature 60 not in {1.0})
#          Predict: 0.8088052531463276
#      Else (feature 2 not in {0.0})
#       If (feature 19 in {1.0})
#        If (feature 67 <= 10.5)
#         If (feature 60 in {0.0})
#          Predict: 2.7589813968885437
#         Else (feature 60 not in {0.0})
#          Predict: 3.1654854810375914
#        Else (feature 67 > 10.5)
#         If (feature 66 <= 12.5)
#          Predict: -1.0372263097310779
#         Else (feature 66 > 12.5)
#          Predict: 0.5233782605933675
#       Else (feature 19 not in {1.0})
#        If (feature 25 in {1.0})
#         If (feature 67 <= 14.5)
#          Predict: -0.7879135438601885
#         Else (feature 67 > 14.5)
#          Predict: 2.1711029200763914
#        Else (feature 25 not in {1.0})
#         If (feature 66 <= 4.5)
#          Predict: 0.5969895962396026
#         Else (feature 66 > 4.5)
#          Predict: 1.5077292507916396
#   Tree 3 (weight 0.1):
#     If (feature 66 <= 7.5)
#      If (feature 8 in {1.0})
#       If (feature 59 in {0.0})
#        If (feature 67 <= 10.5)
#         If (feature 64 <= 152.5)
#          Predict: -0.56519728792804
#         Else (feature 64 > 152.5)
#          Predict: -0.17358869740932462
#        Else (feature 67 > 10.5)
#         If (feature 57 in {0.0})
#          Predict: -0.27592834625836643
#         Else (feature 57 not in {0.0})
#          Predict: 0.5706827152130878
#       Else (feature 59 not in {0.0})
#        If (feature 45 in {1.0})
#         If (feature 61 in {0.0})
#          Predict: -1.2498514951558743
#         Else (feature 61 not in {0.0})
#          Predict: 0.32216272141161095
#        Else (feature 45 not in {1.0})
#         If (feature 64 <= 54.5)
#          Predict: 0.4052939818967384
#         Else (feature 64 > 54.5)
#          Predict: 1.7941759984519068
#      Else (feature 8 not in {1.0})
#       If (feature 5 in {1.0})
#        If (feature 45 in {1.0})
#         If (feature 50 in {0.0})
#          Predict: -0.5686809665535556
#         Else (feature 50 not in {0.0})
#          Predict: -0.02620230655834064
#        Else (feature 45 not in {1.0})
#         If (feature 54 in {0.0})
#          Predict: -0.2610530402333292
#         Else (feature 54 not in {0.0})
#          Predict: 0.19467243337404716
#       Else (feature 5 not in {1.0})
#        If (feature 10 in {1.0})
#         If (feature 67 <= 36.5)
#          Predict: -0.2813074817774435
#         Else (feature 67 > 36.5)
#          Predict: 0.3972857181796818
#        Else (feature 10 not in {1.0})
#         If (feature 63 in {0.0})
#          Predict: -0.04167605771193553
#         Else (feature 63 not in {0.0})
#          Predict: 0.18221430457993373
#     Else (feature 66 > 7.5)
#      If (feature 67 <= 21.5)
#       If (feature 48 in {1.0})
#        If (feature 66 <= 12.5)
#         If (feature 67 <= 13.5)
#          Predict: -0.3724953655963202
#         Else (feature 67 > 13.5)
#          Predict: -0.1660063349153934
#        Else (feature 66 > 12.5)
#         If (feature 67 <= 10.5)
#          Predict: -0.35475293052833407
#         Else (feature 67 > 10.5)
#          Predict: 0.07020537650999355
#       Else (feature 48 not in {1.0})
#        If (feature 49 in {1.0})
#         If (feature 60 in {1.0})
#          Predict: -0.23818745607018907
#         Else (feature 60 not in {1.0})
#          Predict: -0.017539886116545857
#        Else (feature 49 not in {1.0})
#         If (feature 57 in {0.0})
#          Predict: 0.11461095026390851
#         Else (feature 57 not in {0.0})
#          Predict: 0.5391458141147344
#      Else (feature 67 > 21.5)
#       If (feature 69 <= 333.5)
#        If (feature 66 <= 14.5)
#         If (feature 69 <= 72.5)
#          Predict: 0.6746151450261781
#         Else (feature 69 > 72.5)
#          Predict: 0.2635085802241505
#        Else (feature 66 > 14.5)
#         If (feature 68 <= 135.5)
#          Predict: 0.5352032582344138
#         Else (feature 68 > 135.5)
#          Predict: 0.8101436261145858
#       Else (feature 69 > 333.5)
#        If (feature 66 <= 25.5)
#         If (feature 24 in {1.0})
#          Predict: -1.760044726187003
#         Else (feature 24 not in {1.0})
#          Predict: -0.33693226033847207
#        Else (feature 66 > 25.5)
#         If (feature 3 in {1.0})
#          Predict: -2.3778646844266276
#         Else (feature 3 not in {1.0})
#          Predict: 0.9016099614140813
#   Tree 4 (weight 0.1):
#     If (feature 57 in {0.0})
#      If (feature 67 <= 14.5)
#       If (feature 48 in {1.0})
#        If (feature 64 <= 326.5)
#         If (feature 2 in {0.0})
#          Predict: -0.32775603390306135
#         Else (feature 2 not in {0.0})
#          Predict: -0.02642765875936277
#        Else (feature 64 > 326.5)
#         If (feature 66 <= 23.5)
#          Predict: 0.9466211245083558
#         Else (feature 66 > 23.5)
#          Predict: -0.8530431819846676
#       Else (feature 48 not in {1.0})
#        If (feature 2 in {0.0})
#         If (feature 8 in {1.0})
#          Predict: -0.2913541325018416
#         Else (feature 8 not in {1.0})
#          Predict: -0.06520387039348553
#        Else (feature 2 not in {0.0})
#         If (feature 62 in {0.0})
#          Predict: 0.08871148745005725
#         Else (feature 62 not in {0.0})
#          Predict: 0.3878112548209377
#      Else (feature 67 > 14.5)
#       If (feature 47 in {0.0})
#        If (feature 66 <= 6.5)
#         If (feature 67 <= 36.5)
#          Predict: -0.09567873491879778
#         Else (feature 67 > 36.5)
#          Predict: 0.28493329808788287
#        Else (feature 66 > 6.5)
#         If (feature 69 <= 252.5)
#          Predict: 0.15981079480701835
#         Else (feature 69 > 252.5)
#          Predict: -0.11861608805385442
#       Else (feature 47 not in {0.0})
#        If (feature 69 <= 88.5)
#         If (feature 64 <= 80.5)
#          Predict: 0.7770861830260871
#         Else (feature 64 > 80.5)
#          Predict: 1.2754284032619856
#        Else (feature 69 > 88.5)
#         If (feature 60 in {1.0})
#          Predict: -0.04776284415396164
#         Else (feature 60 not in {1.0})
#          Predict: 0.33233893378614815
#     Else (feature 57 not in {0.0})
#      If (feature 2 in {0.0})
#       If (feature 67 <= 11.5)
#        If (feature 5 in {1.0})
#         If (feature 28 in {1.0})
#          Predict: -1.4611138003681785
#         Else (feature 28 not in {1.0})
#          Predict: -0.07194564587466351
#        Else (feature 5 not in {1.0})
#         If (feature 36 in {0.0})
#          Predict: 0.24975131978183215
#         Else (feature 36 not in {0.0})
#          Predict: 1.501441953381357
#       Else (feature 67 > 11.5)
#        If (feature 32 in {1.0})
#         If (feature 69 <= 230.5)
#          Predict: -0.08278271068748909
#         Else (feature 69 > 230.5)
#          Predict: -1.600787900972857
#        Else (feature 32 not in {1.0})
#         If (feature 1 in {0.0})
#          Predict: 0.47883998113963244
#         Else (feature 1 not in {0.0})
#          Predict: 0.9506473364927055
#      Else (feature 2 not in {0.0})
#       If (feature 19 in {1.0})
#        If (feature 67 <= 10.5)
#         If (feature 60 in {0.0})
#          Predict: 2.1390787787547048
#         Else (feature 60 not in {0.0})
#          Predict: 2.575557322556847
#        Else (feature 67 > 10.5)
#         If (feature 66 <= 5.5)
#          Predict: 0.6022468589358625
#         Else (feature 66 > 5.5)
#          Predict: -0.9078893482697049
#       Else (feature 19 not in {1.0})
#        If (feature 38 in {1.0})
#         If (feature 67 <= 9.5)
#          Predict: 2.0751226531783455
#         Else (feature 67 > 9.5)
#          Predict: -0.3414577686562043
#        Else (feature 38 not in {1.0})
#         If (feature 25 in {1.0})
#          Predict: -0.29782468767294384
#         Else (feature 25 not in {1.0})
#          Predict: 1.1926101518736267
#   Tree 5 (weight 0.1):
#     If (feature 66 <= 11.5)
#      If (feature 67 <= 30.5)
#       If (feature 48 in {1.0})
#        If (feature 67 <= 14.5)
#         If (feature 64 <= 326.5)
#          Predict: -0.2811843096725421
#         Else (feature 64 > 326.5)
#          Predict: 0.7855791790253245
#        Else (feature 67 > 14.5)
#         If (feature 60 in {1.0})
#          Predict: -0.25739665614804486
#         Else (feature 60 not in {1.0})
#          Predict: -0.05794031579288139
#       Else (feature 48 not in {1.0})
#        If (feature 8 in {1.0})
#         If (feature 59 in {0.0})
#          Predict: -0.24212831141841648
#         Else (feature 59 not in {0.0})
#          Predict: 0.44740308040958526
#        Else (feature 8 not in {1.0})
#         If (feature 5 in {1.0})
#          Predict: -0.20602036872363577
#         Else (feature 5 not in {1.0})
#          Predict: 0.006602014402281635
#      Else (feature 67 > 30.5)
#       If (feature 69 <= 164.5)
#        If (feature 69 <= 72.5)
#         If (feature 67 <= 35.5)
#          Predict: 0.7283800891727465
#         Else (feature 67 > 35.5)
#          Predict: 0.4493439298236461
#        Else (feature 69 > 72.5)
#         If (feature 64 <= 84.5)
#          Predict: -1.2849248046032462
#         Else (feature 64 > 84.5)
#          Predict: 0.31213980729982976
#       Else (feature 69 > 164.5)
#        If (feature 64 <= 176.5)
#         If (feature 43 in {0.0})
#          Predict: -1.1725140893571222
#         Else (feature 43 not in {0.0})
#          Predict: 0.20693622838569417
#        Else (feature 64 > 176.5)
#         If (feature 69 <= 182.5)
#          Predict: 0.7437421775999976
#         Else (feature 69 > 182.5)
#          Predict: 0.045147677882293756
#     Else (feature 66 > 11.5)
#      If (feature 60 in {1.0})
#       If (feature 51 in {0.0})
#        If (feature 69 <= 68.5)
#         If (feature 64 <= 69.5)
#          Predict: 0.27504838066891996
#         Else (feature 64 > 69.5)
#          Predict: 1.3729538336462361
#        Else (feature 69 > 68.5)
#         If (feature 64 <= 84.5)
#          Predict: -0.5465881961414113
#         Else (feature 64 > 84.5)
#          Predict: -0.03383847430843997
#       Else (feature 51 not in {0.0})
#        If (feature 68 <= 98.5)
#         If (feature 69 <= 106.5)
#          Predict: 0.6422825388673306
#         Else (feature 69 > 106.5)
#          Predict: -0.230670224388778
#        Else (feature 68 > 98.5)
#         If (feature 26 in {1.0})
#          Predict: -0.604319748305243
#         Else (feature 26 not in {1.0})
#          Predict: 1.1305003249462855
#      Else (feature 60 not in {1.0})
#       If (feature 47 in {0.0})
#        If (feature 67 <= 10.5)
#         If (feature 59 in {0.0})
#          Predict: -0.11444887525075606
#         Else (feature 59 not in {0.0})
#          Predict: 1.150234535843746
#        Else (feature 67 > 10.5)
#         If (feature 67 <= 19.5)
#          Predict: 0.2093682969301769
#         Else (feature 67 > 19.5)
#          Predict: 0.4300893612225046
#       Else (feature 47 not in {0.0})
#        If (feature 69 <= 145.5)
#         If (feature 69 <= 88.5)
#          Predict: 1.102723741767361
#         Else (feature 69 > 88.5)
#          Predict: 0.6107039613176238
#        Else (feature 69 > 145.5)
#         If (feature 64 <= 152.5)
#          Predict: -1.0946804051482903
#         Else (feature 64 > 152.5)
#          Predict: 0.2717601808040482
#   Tree 6 (weight 0.1):
#     If (feature 67 <= 11.5)
#      If (feature 63 in {0.0})
#       If (feature 62 in {0.0})
#        If (feature 66 <= 11.5)
#         If (feature 64 <= 167.5)
#          Predict: -0.22238435400132336
#         Else (feature 64 > 167.5)
#          Predict: -0.05298700796753939
#        Else (feature 66 > 11.5)
#         If (feature 5 in {1.0})
#          Predict: -0.4815595771869071
#         Else (feature 5 not in {1.0})
#          Predict: 0.05763343815826526
#       Else (feature 62 not in {0.0})
#        If (feature 2 in {0.0})
#         If (feature 43 in {0.0})
#          Predict: -0.07529719236596677
#         Else (feature 43 not in {0.0})
#          Predict: 0.1478588861388905
#        Else (feature 2 not in {0.0})
#         If (feature 65 <= 858.0)
#          Predict: 0.47113148231421437
#         Else (feature 65 > 858.0)
#          Predict: 0.007917921089863673
#      Else (feature 63 not in {0.0})
#       If (feature 47 in {0.0})
#        If (feature 54 in {0.0})
#         If (feature 15 in {0.0})
#          Predict: -0.10414606688667367
#         Else (feature 15 not in {0.0})
#          Predict: 0.8494259702001336
#        Else (feature 54 not in {0.0})
#         If (feature 1 in {0.0})
#          Predict: 0.34643229599715736
#         Else (feature 1 not in {0.0})
#          Predict: 2.3471059476336054
#       Else (feature 47 not in {0.0})
#        If (feature 0 in {0.0})
#         If (feature 2 in {0.0})
#          Predict: 0.15703689354971187
#         Else (feature 2 not in {0.0})
#          Predict: 0.7218881785660944
#        Else (feature 0 not in {0.0})
#         If (feature 46 in {1.0})
#          Predict: -0.06230094521345067
#         Else (feature 46 not in {1.0})
#          Predict: 0.995992416947778
#     Else (feature 67 > 11.5)
#      If (feature 47 in {0.0})
#       If (feature 66 <= 6.5)
#        If (feature 59 in {0.0})
#         If (feature 67 <= 36.5)
#          Predict: -0.08744477288093852
#         Else (feature 67 > 36.5)
#          Predict: 0.2334268486052483
#        Else (feature 59 not in {0.0})
#         If (feature 67 <= 13.5)
#          Predict: 0.3505820681955388
#         Else (feature 67 > 13.5)
#          Predict: 1.0709267803714624
#       Else (feature 66 > 6.5)
#        If (feature 60 in {1.0})
#         If (feature 59 in {0.0})
#          Predict: -0.030010492938695312
#         Else (feature 59 not in {0.0})
#          Predict: 1.24042752732635
#        Else (feature 60 not in {1.0})
#         If (feature 69 <= 333.5)
#          Predict: 0.16091982629154242
#         Else (feature 69 > 333.5)
#          Predict: -0.2672875016452676
#      Else (feature 47 not in {0.0})
#       If (feature 69 <= 111.5)
#        If (feature 68 <= 88.5)
#         If (feature 69 <= 88.5)
#          Predict: 0.5590030175004452
#         Else (feature 69 > 88.5)
#          Predict: 0.1569139049618885
#        Else (feature 68 > 88.5)
#         If (feature 69 <= 106.5)
#          Predict: 2.038252307884247
#         Else (feature 69 > 106.5)
#          Predict: 1.404030723764223
#       Else (feature 69 > 111.5)
#        If (feature 64 <= 117.5)
#         If (feature 69 <= 121.5)
#          Predict: -0.27261630081792376
#         Else (feature 69 > 121.5)
#          Predict: -0.7224143121718526
#        Else (feature 64 > 117.5)
#         If (feature 69 <= 121.5)
#          Predict: 1.1718342542483429
#         Else (feature 69 > 121.5)
#          Predict: 0.03315884173179435
#   Tree 7 (weight 0.1):
#     If (feature 57 in {0.0})
#      If (feature 67 <= 21.5)
#       If (feature 62 in {0.0})
#        If (feature 63 in {0.0})
#         If (feature 58 in {0.0})
#          Predict: -0.10827225816638071
#         Else (feature 58 not in {0.0})
#          Predict: 0.36764835578907507
#        Else (feature 63 not in {0.0})
#         If (feature 50 in {1.0})
#          Predict: -0.3865384189767146
#         Else (feature 50 not in {1.0})
#          Predict: 0.11535734434918794
#       Else (feature 62 not in {0.0})
#        If (feature 5 in {1.0})
#         If (feature 42 in {0.0})
#          Predict: -0.31518600041902667
#         Else (feature 42 not in {0.0})
#          Predict: 0.09971969697070038
#        Else (feature 5 not in {1.0})
#         If (feature 47 in {0.0})
#          Predict: 0.03234424505751742
#         Else (feature 47 not in {0.0})
#          Predict: 0.22214800573613508
#      Else (feature 67 > 21.5)
#       If (feature 69 <= 230.5)
#        If (feature 68 <= 177.5)
#         If (feature 69 <= 194.5)
#          Predict: 0.15573429487725857
#         Else (feature 69 > 194.5)
#          Predict: -0.46107845174309553
#        Else (feature 68 > 177.5)
#         If (feature 69 <= 209.5)
#          Predict: 1.5694567575533689
#         Else (feature 69 > 209.5)
#          Predict: 0.6033087564804027
#       Else (feature 69 > 230.5)
#        If (feature 64 <= 245.5)
#         If (feature 68 <= 198.5)
#          Predict: -1.3295086009273895
#         Else (feature 68 > 198.5)
#          Predict: -0.5355086548973772
#        Else (feature 64 > 245.5)
#         If (feature 69 <= 252.5)
#          Predict: 1.0274302511538063
#         Else (feature 69 > 252.5)
#          Predict: -0.0999438175396109
#     Else (feature 57 not in {0.0})
#      If (feature 2 in {0.0})
#       If (feature 67 <= 22.5)
#        If (feature 69 <= 164.5)
#         If (feature 68 <= 128.5)
#          Predict: 0.26141691669133094
#         Else (feature 68 > 128.5)
#          Predict: 1.1249654267496187
#        Else (feature 69 > 164.5)
#         If (feature 68 <= 151.5)
#          Predict: -0.27074870276888646
#         Else (feature 68 > 151.5)
#          Predict: 0.31716193367249984
#       Else (feature 67 > 22.5)
#        If (feature 68 <= 142.5)
#         If (feature 67 <= 24.5)
#          Predict: 1.0837186968437458
#         Else (feature 67 > 24.5)
#          Predict: 0.3462086070230432
#        Else (feature 68 > 142.5)
#         If (feature 67 <= 33.5)
#          Predict: 1.3119537681601723
#         Else (feature 67 > 33.5)
#          Predict: 0.6772759978649295
#      Else (feature 2 not in {0.0})
#       If (feature 17 in {0.0})
#        If (feature 65 <= 541.5)
#         If (feature 66 <= 18.5)
#          Predict: 1.5724016705812496
#         Else (feature 66 > 18.5)
#          Predict: -2.6650897896273484
#        Else (feature 65 > 541.5)
#         If (feature 64 <= 107.5)
#          Predict: -0.24871319803022862
#         Else (feature 64 > 107.5)
#          Predict: 0.7904018667005134
#       Else (feature 17 not in {0.0})
#        If (feature 66 <= 11.5)
#         If (feature 63 in {1.0})
#          Predict: 2.16898519491555
#         Else (feature 63 not in {1.0})
#          Predict: 2.3056028149873593
#        Else (feature 66 > 11.5)
#         Predict: 1.3972386110861557
#   Tree 8 (weight 0.1):
#     If (feature 8 in {1.0})
#      If (feature 29 in {0.0})
#       If (feature 59 in {0.0})
#        If (feature 34 in {0.0})
#         If (feature 42 in {0.0})
#          Predict: -0.2706154227162376
#         Else (feature 42 not in {0.0})
#          Predict: -0.037222133420284416
#        Else (feature 34 not in {0.0})
#         If (feature 48 in {1.0})
#          Predict: -0.5543916992780864
#         Else (feature 48 not in {1.0})
#          Predict: 0.30518345059523255
#       Else (feature 59 not in {0.0})
#        If (feature 13 in {0.0})
#         If (feature 67 <= 14.5)
#          Predict: 0.007913424314418606
#         Else (feature 67 > 14.5)
#          Predict: 1.2802606310950104
#        Else (feature 13 not in {0.0})
#         If (feature 67 <= 13.5)
#          Predict: 2.745080232297926
#         Else (feature 67 > 13.5)
#          Predict: -1.637044080292899
#      Else (feature 29 not in {0.0})
#       If (feature 62 in {0.0})
#        If (feature 65 <= 123.5)
#         If (feature 66 <= 9.5)
#          Predict: 2.651836892575767
#         Else (feature 66 > 9.5)
#          Predict: -2.1963881496218
#        Else (feature 65 > 123.5)
#         If (feature 68 <= 47.5)
#          Predict: -0.6933111790905973
#         Else (feature 68 > 47.5)
#          Predict: 0.1719054248191415
#       Else (feature 62 not in {0.0})
#        If (feature 66 <= 3.5)
#         If (feature 53 in {1.0})
#          Predict: -1.7020688903019539
#         Else (feature 53 not in {1.0})
#          Predict: -1.2053942876115136
#        Else (feature 66 > 3.5)
#         If (feature 57 in {1.0})
#          Predict: -3.4891957347272116
#         Else (feature 57 not in {1.0})
#          Predict: 1.235124660466938
#     Else (feature 8 not in {1.0})
#      If (feature 10 in {1.0})
#       If (feature 52 in {1.0})
#        If (feature 23 in {0.0})
#         If (feature 67 <= 34.5)
#          Predict: -0.518845009480001
#         Else (feature 67 > 34.5)
#          Predict: 0.4245947648575349
#        Else (feature 23 not in {0.0})
#         If (feature 69 <= 92.5)
#          Predict: 1.9401912315024157
#         Else (feature 69 > 92.5)
#          Predict: 0.18701000475893875
#       Else (feature 52 not in {1.0})
#        If (feature 67 <= 11.5)
#         If (feature 68 <= 219.5)
#          Predict: -0.3012958713512818
#         Else (feature 68 > 219.5)
#          Predict: 0.12080218747400448
#        Else (feature 67 > 11.5)
#         If (feature 69 <= 333.5)
#          Predict: -0.0893534742666382
#         Else (feature 69 > 333.5)
#          Predict: -0.698021172586991
#      Else (feature 10 not in {1.0})
#       If (feature 5 in {1.0})
#        If (feature 45 in {1.0})
#         If (feature 50 in {0.0})
#          Predict: -0.4625986785072925
#         Else (feature 50 not in {0.0})
#          Predict: 0.14812536408714214
#        Else (feature 45 not in {1.0})
#         If (feature 52 in {1.0})
#          Predict: -0.4326667780007815
#         Else (feature 52 not in {1.0})
#          Predict: -0.09745356335991184
#       Else (feature 5 not in {1.0})
#        If (feature 66 <= 7.5)
#         If (feature 62 in {0.0})
#          Predict: -0.030627297968103925
#         Else (feature 62 not in {0.0})
#          Predict: 0.09934520052620353
#        Else (feature 66 > 7.5)
#         If (feature 60 in {1.0})
#          Predict: 0.03345113548716704
#         Else (feature 60 not in {1.0})
#          Predict: 0.19911751100949585
#   Tree 9 (weight 0.1):
#     If (feature 67 <= 13.5)
#      If (feature 48 in {1.0})
#       If (feature 68 <= 198.5)
#        If (feature 66 <= 21.5)
#         If (feature 3 in {0.0})
#          Predict: -0.2722912744887348
#         Else (feature 3 not in {0.0})
#          Predict: -0.008811730233562244
#        Else (feature 66 > 21.5)
#         If (feature 69 <= 209.5)
#          Predict: 0.6562710784510984
#         Else (feature 69 > 209.5)
#          Predict: -1.8657613269918596
#       Else (feature 68 > 198.5)
#        If (feature 67 <= 7.5)
#         If (feature 2 in {0.0})
#          Predict: 2.9168620344144602
#         Else (feature 2 not in {0.0})
#          Predict: 3.23249416794953
#        Else (feature 67 > 7.5)
#         If (feature 2 in {0.0})
#          Predict: -0.05158504673709837
#         Else (feature 2 not in {0.0})
#          Predict: 0.6040453038919292
#      Else (feature 48 not in {1.0})
#       If (feature 2 in {0.0})
#        If (feature 59 in {0.0})
#         If (feature 67 <= 10.5)
#          Predict: -0.11816757146141202
#         Else (feature 67 > 10.5)
#          Predict: -0.014049507512529402
#        Else (feature 59 not in {0.0})
#         If (feature 64 <= 45.5)
#          Predict: 0.10319835413852024
#         Else (feature 64 > 45.5)
#          Predict: 0.5484514302168981
#       Else (feature 2 not in {0.0})
#        If (feature 16 in {0.0})
#         If (feature 54 in {1.0})
#          Predict: -0.43712246179184155
#         Else (feature 54 not in {1.0})
#          Predict: 0.13119777406206143
#        Else (feature 16 not in {0.0})
#         If (feature 55 in {1.0})
#          Predict: -0.6902094053273545
#         Else (feature 55 not in {1.0})
#          Predict: 0.9292061427161902
#     Else (feature 67 > 13.5)
#      If (feature 69 <= 252.5)
#       If (feature 68 <= 219.5)
#        If (feature 59 in {0.0})
#         If (feature 47 in {0.0})
#          Predict: 0.022871280780780004
#         Else (feature 47 not in {0.0})
#          Predict: 0.24147933901819305
#        Else (feature 59 not in {0.0})
#         If (feature 7 in {1.0})
#          Predict: -0.17532805099342566
#         Else (feature 7 not in {1.0})
#          Predict: 1.3794784364600736
#       Else (feature 68 > 219.5)
#        If (feature 64 <= 245.5)
#         If (feature 4 in {0.0})
#          Predict: 0.5798982483779292
#         Else (feature 4 not in {0.0})
#          Predict: 2.927943086670962
#        Else (feature 64 > 245.5)
#         If (feature 67 <= 18.5)
#          Predict: 1.9614433563408107
#         Else (feature 67 > 18.5)
#          Predict: 1.3538053150309375
#      Else (feature 69 > 252.5)
#       If (feature 68 <= 219.5)
#        If (feature 64 <= 277.5)
#         If (feature 67 <= 17.5)
#          Predict: -0.5957912115427103
#         Else (feature 67 > 17.5)
#          Predict: -1.1022340646666402
#        Else (feature 64 > 277.5)
#         If (feature 7 in {1.0})
#          Predict: 0.7315090448053142
#         Else (feature 7 not in {1.0})
#          Predict: 0.87507818495714
#       Else (feature 68 > 219.5)
#        If (feature 64 <= 326.5)
#         If (feature 69 <= 287.5)
#          Predict: 0.08123152436239978
#         Else (feature 69 > 287.5)
#          Predict: -0.3682736766093164
#        Else (feature 64 > 326.5)
#         If (feature 69 <= 333.5)
#          Predict: 1.2456669475723297
#         Else (feature 69 > 333.5)
#          Predict: -0.12387669758957244
#   Tree 10 (weight 0.1):
#     If (feature 57 in {0.0})
#      If (feature 67 <= 30.5)
#       If (feature 10 in {1.0})
#        If (feature 31 in {1.0})
#         If (feature 67 <= 26.5)
#          Predict: -0.5447249040961266
#         Else (feature 67 > 26.5)
#          Predict: -1.9927397479397264
#        Else (feature 31 not in {1.0})
#         If (feature 37 in {0.0})
#          Predict: -0.18191963745895065
#         Else (feature 37 not in {0.0})
#          Predict: 0.22076849497484347
#       Else (feature 10 not in {1.0})
#        If (feature 8 in {1.0})
#         If (feature 29 in {0.0})
#          Predict: -0.19444053464187586
#         Else (feature 29 not in {0.0})
#          Predict: 0.32903069145305125
#        Else (feature 8 not in {1.0})
#         If (feature 5 in {1.0})
#          Predict: -0.15848062150856962
#         Else (feature 5 not in {1.0})
#          Predict: 0.020777772158049008
#      Else (feature 67 > 30.5)
#       If (feature 69 <= 121.5)
#        If (feature 64 <= 117.5)
#         If (feature 69 <= 106.5)
#          Predict: 0.27661476160495935
#         Else (feature 69 > 106.5)
#          Predict: -0.9018031741155874
#        Else (feature 64 > 117.5)
#         If (feature 67 <= 33.5)
#          Predict: 0.8156586613798984
#         Else (feature 67 > 33.5)
#          Predict: 0.3998774152251711
#       Else (feature 69 > 121.5)
#        If (feature 64 <= 134.5)
#         If (feature 64 <= 128.5)
#          Predict: -1.6282647033935032
#         Else (feature 64 > 128.5)
#          Predict: -0.5674734771451722
#        Else (feature 64 > 134.5)
#         If (feature 69 <= 133.5)
#          Predict: 0.48127281256733345
#         Else (feature 69 > 133.5)
#          Predict: 0.0958343661742797
#     Else (feature 57 not in {0.0})
#      If (feature 2 in {0.0})
#       If (feature 65 <= 1389.5)
#        If (feature 64 <= 189.5)
#         If (feature 7 in {1.0})
#          Predict: -0.18192695788785118
#         Else (feature 7 not in {1.0})
#          Predict: 0.3304029648307747
#        Else (feature 64 > 189.5)
#         If (feature 21 in {1.0})
#          Predict: -1.352163751538803
#         Else (feature 21 not in {1.0})
#          Predict: 0.898773239276519
#       Else (feature 65 > 1389.5)
#        If (feature 64 <= 277.5)
#         If (feature 65 <= 2003.0)
#          Predict: 0.014147414338017594
#         Else (feature 65 > 2003.0)
#          Predict: -0.9811281215740137
#        Else (feature 64 > 277.5)
#         If (feature 23 in {0.0})
#          Predict: 0.5413914635301994
#         Else (feature 23 not in {0.0})
#          Predict: 2.4104178989078306
#      Else (feature 2 not in {0.0})
#       If (feature 19 in {1.0})
#        If (feature 67 <= 10.5)
#         If (feature 60 in {0.0})
#          Predict: 1.2705916270448616
#         Else (feature 60 not in {0.0})
#          Predict: 1.9293495706871397
#        Else (feature 67 > 10.5)
#         If (feature 66 <= 12.5)
#          Predict: -0.9138749510166747
#         Else (feature 66 > 12.5)
#          Predict: 0.43534676299198694
#       Else (feature 19 not in {1.0})
#        If (feature 38 in {1.0})
#         If (feature 61 in {1.0})
#          Predict: -1.894789801970305
#         Else (feature 61 not in {1.0})
#          Predict: 0.16517190837625897
#        Else (feature 38 not in {1.0})
#         If (feature 68 <= 142.5)
#          Predict: 0.5884935533408578
#         Else (feature 68 > 142.5)
#          Predict: 1.0737768616567696
#   Tree 11 (weight 0.1):
#     If (feature 66 <= 12.5)
#      If (feature 48 in {1.0})
#       If (feature 67 <= 21.5)
#        If (feature 3 in {0.0})
#         If (feature 23 in {0.0})
#          Predict: -0.1883982976755555
#         Else (feature 23 not in {0.0})
#          Predict: 0.22644262466148163
#        Else (feature 3 not in {0.0})
#         If (feature 26 in {0.0})
#          Predict: 8.39031380226162E-4
#         Else (feature 26 not in {0.0})
#          Predict: 1.1533418183891
#       Else (feature 67 > 21.5)
#        If (feature 69 <= 116.5)
#         If (feature 68 <= 84.5)
#          Predict: 0.125962748739462
#         Else (feature 68 > 84.5)
#          Predict: 1.296743855029177
#        Else (feature 69 > 116.5)
#         If (feature 64 <= 122.5)
#          Predict: -0.7788622457346499
#         Else (feature 64 > 122.5)
#          Predict: -0.06099522018209327
#      Else (feature 48 not in {1.0})
#       If (feature 64 <= 102.5)
#        If (feature 69 <= 80.5)
#         If (feature 64 <= 80.5)
#          Predict: -0.007394403277682434
#         Else (feature 64 > 80.5)
#          Predict: 1.0452727660261176
#        Else (feature 69 > 80.5)
#         If (feature 68 <= 58.5)
#          Predict: -0.47592175457307684
#         Else (feature 68 > 58.5)
#          Predict: -0.15042059355328838
#       Else (feature 64 > 102.5)
#        If (feature 69 <= 106.5)
#         If (feature 68 <= 88.5)
#          Predict: 0.6639528742637557
#         Else (feature 68 > 88.5)
#          Predict: 1.6478595387885637
#        Else (feature 69 > 106.5)
#         If (feature 64 <= 122.5)
#          Predict: -0.1900939177171126
#         Else (feature 64 > 122.5)
#          Predict: 0.03847341688540598
#     Else (feature 66 > 12.5)
#      If (feature 69 <= 92.5)
#       If (feature 64 <= 89.5)
#        If (feature 69 <= 72.5)
#         If (feature 64 <= 73.5)
#          Predict: 0.1744992795311667
#         Else (feature 64 > 73.5)
#          Predict: 1.1932982738618008
#        Else (feature 69 > 72.5)
#         If (feature 68 <= 50.5)
#          Predict: -0.4557440716275685
#         Else (feature 68 > 50.5)
#          Predict: 0.18865826876680708
#       Else (feature 64 > 89.5)
#        If (feature 68 <= 62.5)
#         If (feature 68 <= 54.5)
#          Predict: 0.4385570574821399
#         Else (feature 68 > 54.5)
#          Predict: 0.8844100778788748
#        Else (feature 68 > 62.5)
#         If (feature 64 <= 93.5)
#          Predict: 0.7409948323091956
#         Else (feature 64 > 93.5)
#          Predict: 1.5597822139019588
#      Else (feature 69 > 92.5)
#       If (feature 64 <= 98.5)
#        If (feature 66 <= 17.5)
#         If (feature 67 <= 26.5)
#          Predict: -0.48401474228305086
#         Else (feature 67 > 26.5)
#          Predict: -2.999970629027323
#        Else (feature 66 > 17.5)
#         If (feature 51 in {0.0})
#          Predict: -1.7665555111517448
#         Else (feature 51 not in {0.0})
#          Predict: 0.08913537065080608
#       Else (feature 64 > 98.5)
#        If (feature 69 <= 111.5)
#         If (feature 68 <= 79.5)
#          Predict: 0.2827371326465996
#         Else (feature 68 > 79.5)
#          Predict: 1.1285074686999412
#        Else (feature 69 > 111.5)
#         If (feature 64 <= 122.5)
#          Predict: -0.5364948264706978
#         Else (feature 64 > 122.5)
#          Predict: 0.10207910929828712
#   Tree 12 (weight 0.1):
#     If (feature 69 <= 164.5)
#      If (feature 64 <= 159.5)
#       If (feature 69 <= 151.5)
#        If (feature 64 <= 146.5)
#         If (feature 69 <= 139.5)
#          Predict: 0.009327590982414783
#         Else (feature 69 > 139.5)
#          Predict: -0.28309280726181046
#        Else (feature 64 > 146.5)
#         If (feature 68 <= 128.5)
#          Predict: 0.68177676478099
#         Else (feature 68 > 128.5)
#          Predict: 1.5582045569348946
#       Else (feature 69 > 151.5)
#        If (feature 68 <= 128.5)
#         If (feature 66 <= 18.5)
#          Predict: -0.41892510294753466
#         Else (feature 66 > 18.5)
#          Predict: -1.3391750124007256
#        Else (feature 68 > 128.5)
#         If (feature 69 <= 158.5)
#          Predict: 0.13238950284281678
#         Else (feature 69 > 158.5)
#          Predict: -0.2621326539086507
#      Else (feature 64 > 159.5)
#       If (feature 68 <= 142.5)
#        If (feature 67 <= 25.5)
#         If (feature 69 <= 158.5)
#          Predict: 1.5051691187114657
#         Else (feature 69 > 158.5)
#          Predict: 0.3541828519576624
#        Else (feature 67 > 25.5)
#         If (feature 65 <= 996.5)
#          Predict: 0.3528371947099921
#         Else (feature 65 > 996.5)
#          Predict: 0.5888050395274107
#       Else (feature 68 > 142.5)
#        If (feature 67 <= 25.5)
#         If (feature 64 <= 167.5)
#          Predict: 1.4704472050319246
#         Else (feature 64 > 167.5)
#          Predict: 2.378527730962651
#        Else (feature 67 > 25.5)
#         If (feature 67 <= 32.5)
#          Predict: 0.6442998629332085
#         Else (feature 67 > 32.5)
#          Predict: 0.3761447649786776
#     Else (feature 69 > 164.5)
#      If (feature 64 <= 176.5)
#       If (feature 67 <= 17.5)
#        If (feature 66 <= 18.5)
#         If (feature 64 <= 167.5)
#          Predict: -0.35585458993574137
#         Else (feature 64 > 167.5)
#          Predict: -0.11712731174713413
#        Else (feature 66 > 18.5)
#         If (feature 67 <= 14.5)
#          Predict: -0.9474018372446295
#         Else (feature 67 > 14.5)
#          Predict: -2.301829914704517
#       Else (feature 67 > 17.5)
#        If (feature 66 <= 10.5)
#         If (feature 69 <= 172.5)
#          Predict: -0.3716236723506943
#         Else (feature 69 > 172.5)
#          Predict: -0.7533669015717404
#        Else (feature 66 > 10.5)
#         If (feature 68 <= 142.5)
#          Predict: -1.1632746719252738
#         Else (feature 68 > 142.5)
#          Predict: 0.28461421043002283
#      Else (feature 64 > 176.5)
#       If (feature 69 <= 182.5)
#        If (feature 68 <= 151.5)
#         If (feature 69 <= 172.5)
#          Predict: 0.8411490137625097
#         Else (feature 69 > 172.5)
#          Predict: 0.142641378019761
#        Else (feature 68 > 151.5)
#         If (feature 68 <= 163.5)
#          Predict: 1.2157694451759533
#         Else (feature 68 > 163.5)
#          Predict: 2.0408621403491876
#       Else (feature 69 > 182.5)
#        If (feature 64 <= 189.5)
#         If (feature 68 <= 151.5)
#          Predict: -1.20089486496637
#         Else (feature 68 > 151.5)
#          Predict: -0.40655038657608333
#        Else (feature 64 > 189.5)
#         If (feature 69 <= 209.5)
#          Predict: 0.623104972896458
#         Else (feature 69 > 209.5)
#          Predict: -0.08193407960535597
#   Tree 13 (weight 0.1):
#     If (feature 64 <= 84.5)
#      If (feature 69 <= 76.5)
#       If (feature 64 <= 73.5)
#        If (feature 69 <= 64.5)
#         If (feature 64 <= 60.5)
#          Predict: -0.047379717222763136
#         Else (feature 64 > 60.5)
#          Predict: 0.7510604212112901
#        Else (feature 69 > 64.5)
#         If (feature 68 <= 43.5)
#          Predict: -0.39748696081765933
#         Else (feature 68 > 43.5)
#          Predict: -0.0035572531374278194
#       Else (feature 64 > 73.5)
#        If (feature 68 <= 50.5)
#         If (feature 69 <= 72.5)
#          Predict: 0.8226536079713055
#         Else (feature 69 > 72.5)
#          Predict: -0.23887066247357355
#        Else (feature 68 > 50.5)
#         If (feature 64 <= 76.5)
#          Predict: 0.5445615462286001
#         Else (feature 64 > 76.5)
#          Predict: 1.4682309288615827
#      Else (feature 69 > 76.5)
#       If (feature 67 <= 25.5)
#        If (feature 68 <= 47.5)
#         If (feature 14 in {0.0})
#          Predict: -0.5488993225927088
#         Else (feature 14 not in {0.0})
#          Predict: 0.401627183170527
#        Else (feature 68 > 47.5)
#         If (feature 69 <= 80.5)
#          Predict: -0.076041968528088
#         Else (feature 69 > 80.5)
#          Predict: -0.28425117250698045
#       Else (feature 67 > 25.5)
#        If (feature 68 <= 47.5)
#         If (feature 21 in {0.0})
#          Predict: -1.68102040868272
#         Else (feature 21 not in {0.0})
#          Predict: 0.23659327047403167
#        Else (feature 68 > 47.5)
#         If (feature 67 <= 26.5)
# ...
#        Else (feature 68 > 47.5)
#         If (feature 56 in {1.0})
#          Predict: -0.9852955998416629
#         Else (feature 56 not in {1.0})
#          Predict: 0.5144935761508808
#      Else (feature 4 not in {1.0})
#       If (feature 58 in {0.0})
#        If (feature 15 in {0.0})
#         If (feature 67 <= 25.5)
#          Predict: -0.02682112468970912
#         Else (feature 67 > 25.5)
#          Predict: 0.058895731447106546
#        Else (feature 15 not in {0.0})
#         If (feature 44 in {0.0})
#          Predict: 0.024525714561900957
#         Else (feature 44 not in {0.0})
#          Predict: 0.46455753962453283
#       Else (feature 58 not in {0.0})
#        If (feature 68 <= 116.5)
#         If (feature 69 <= 106.5)
#          Predict: -0.13080771530049695
#         Else (feature 69 > 106.5)
#          Predict: 0.655881775942646
#        Else (feature 68 > 116.5)
#         If (feature 67 <= 11.5)
#          Predict: -0.19162613747073776
#         Else (feature 67 > 11.5)
#          Predict: 0.18749598684797814
#     Else (feature 62 not in {0.0})
#      If (feature 54 in {0.0})
#       If (feature 39 in {1.0})
#        If (feature 4 in {1.0})
#         If (feature 66 <= 3.5)
#          Predict: 0.3508584417075557
#         Else (feature 66 > 3.5)
#          Predict: -1.1788222304351794
#        Else (feature 4 not in {1.0})
#         If (feature 57 in {0.0})
#          Predict: -0.16854821936299336
#         Else (feature 57 not in {0.0})
#          Predict: 1.2073258631338248
#       Else (feature 39 not in {1.0})
#        If (feature 32 in {1.0})
#         If (feature 0 in {0.0})
#          Predict: -0.24846509007707646
#         Else (feature 0 not in {0.0})
#          Predict: 0.5543939644957656
#        Else (feature 32 not in {1.0})
#         If (feature 56 in {1.0})
#          Predict: -0.17543688658611437
#         Else (feature 56 not in {1.0})
#          Predict: 0.05090349711149955
#      Else (feature 54 not in {0.0})
#       If (feature 7 in {0.0})
#        If (feature 37 in {1.0})
#         If (feature 66 <= 2.5)
#          Predict: 2.2239405485196095
#         Else (feature 66 > 2.5)
#          Predict: -1.1865137138850024
#        Else (feature 37 not in {1.0})
#         If (feature 1 in {0.0})
#          Predict: 0.14158264330654083
#         Else (feature 1 not in {0.0})
#          Predict: 0.7286378182581732
#       Else (feature 7 not in {0.0})
#        If (feature 67 <= 31.5)
#         If (feature 65 <= 208.5)
#          Predict: -1.6312016700470977
#         Else (feature 65 > 208.5)
#          Predict: 0.975069772170329
#        Else (feature 67 > 31.5)
#         If (feature 65 <= 2451.5)
#          Predict: -2.4188510490527206
#         Else (feature 65 > 2451.5)
#          Predict: 1.3778130224337115
#   Tree 16 (weight 0.1):
#     If (feature 55 in {1.0})
#      If (feature 11 in {0.0})
#       If (feature 69 <= 287.5)
#        If (feature 36 in {0.0})
#         If (feature 61 in {1.0})
#          Predict: -0.31332760297918816
#         Else (feature 61 not in {1.0})
#          Predict: -0.14542045723031652
#        Else (feature 36 not in {0.0})
#         If (feature 46 in {0.0})
#          Predict: -0.12084188994817867
#         Else (feature 46 not in {0.0})
#          Predict: 1.332115604082294
#       Else (feature 69 > 287.5)
#        If (feature 66 <= 18.5)
#         If (feature 65 <= 2451.5)
#          Predict: 0.3860217516969517
#         Else (feature 65 > 2451.5)
#          Predict: -0.2658402417278804
#        Else (feature 66 > 18.5)
#         If (feature 67 <= 15.5)
#          Predict: -0.5362001647834157
#         Else (feature 67 > 15.5)
#          Predict: -1.4675358500456934
#      Else (feature 11 not in {0.0})
#       If (feature 9 in {1.0})
#        If (feature 67 <= 8.5)
#         Predict: 2.7112428618433517
#        Else (feature 67 > 8.5)
#         If (feature 68 <= 79.5)
#          Predict: -0.3937132070756933
#         Else (feature 68 > 79.5)
#          Predict: -1.407444486715909
#       Else (feature 9 not in {1.0})
#        If (feature 60 in {1.0})
#         If (feature 64 <= 89.5)
#          Predict: 1.3828149158106682
#         Else (feature 64 > 89.5)
#          Predict: -0.339929876721518
#        Else (feature 60 not in {1.0})
#         If (feature 68 <= 177.5)
#          Predict: 1.3040100126528988
#         Else (feature 68 > 177.5)
#          Predict: 0.26869161923116636
#     Else (feature 55 not in {1.0})
#      If (feature 2 in {0.0})
#       If (feature 31 in {0.0})
#        If (feature 65 <= 580.5)
#         If (feature 44 in {0.0})
#          Predict: -0.053323063389911975
#         Else (feature 44 not in {0.0})
#          Predict: 0.04560969176321072
#        Else (feature 65 > 580.5)
#         If (feature 56 in {1.0})
#          Predict: -0.15808960597343988
#         Else (feature 56 not in {1.0})
#          Predict: 0.01717367557029488
#       Else (feature 31 not in {0.0})
#        If (feature 9 in {0.0})
#         If (feature 3 in {0.0})
#          Predict: -0.02056952093566362
#         Else (feature 3 not in {0.0})
#          Predict: 0.6443554067581934
#        Else (feature 9 not in {0.0})
#         If (feature 64 <= 107.5)
#          Predict: 1.4070903357909001
#         Else (feature 64 > 107.5)
#          Predict: 0.7270452787216484
#      Else (feature 2 not in {0.0})
#       If (feature 31 in {1.0})
#        If (feature 67 <= 29.5)
#         If (feature 49 in {1.0})
#          Predict: -1.4935404878756628
#         Else (feature 49 not in {1.0})
#          Predict: -0.4256723792434163
#        Else (feature 67 > 29.5)
#         If (feature 66 <= 7.5)
#          Predict: 0.18892768786466207
#         Else (feature 66 > 7.5)
#          Predict: 2.3105858335597045
#       Else (feature 31 not in {1.0})
#        If (feature 28 in {1.0})
#         If (feature 62 in {1.0})
#          Predict: -0.8791707668438098
#         Else (feature 62 not in {1.0})
#          Predict: -0.2206345381568156
#        Else (feature 28 not in {1.0})
#         If (feature 16 in {0.0})
#          Predict: 0.09879904428848216
#         Else (feature 16 not in {0.0})
#          Predict: 0.5305547864999194
#   Tree 17 (weight 0.1):
#     If (feature 57 in {0.0})
#      If (feature 66 <= 5.5)
#       If (feature 53 in {0.0})
#        If (feature 49 in {0.0})
#         If (feature 38 in {1.0})
#          Predict: -0.15596467581867426
#         Else (feature 38 not in {1.0})
#          Predict: 0.0038181982176876098
#        Else (feature 49 not in {0.0})
#         If (feature 3 in {0.0})
#          Predict: 0.06700106170027624
#         Else (feature 3 not in {0.0})
#          Predict: 0.5226309734703053
#       Else (feature 53 not in {0.0})
#        If (feature 10 in {1.0})
#         If (feature 69 <= 111.5)
#          Predict: -0.500921908837807
#         Else (feature 69 > 111.5)
#          Predict: 0.5588644735859126
#        Else (feature 10 not in {1.0})
#         If (feature 1 in {1.0})
#          Predict: -0.1811996434189629
#         Else (feature 1 not in {1.0})
#          Predict: 0.23273881166440696
#      Else (feature 66 > 5.5)
#       If (feature 67 <= 21.5)
#        If (feature 60 in {1.0})
#         If (feature 66 <= 17.5)
#          Predict: -0.06158859939496822
#         Else (feature 66 > 17.5)
#          Predict: -0.22185617017964188
#        Else (feature 60 not in {1.0})
#         If (feature 56 in {1.0})
#          Predict: -0.23384976616529768
#         Else (feature 56 not in {1.0})
#          Predict: -0.012293919342325118
#       Else (feature 67 > 21.5)
#        If (feature 52 in {0.0})
#         If (feature 51 in {1.0})
#          Predict: -0.14188868407632735
#         Else (feature 51 not in {1.0})
#          Predict: 0.03994351258334473
#        Else (feature 52 not in {0.0})
#         If (feature 25 in {1.0})
#          Predict: -0.6598583021347129
#         Else (feature 25 not in {1.0})
#          Predict: 0.28104533536138576
#     Else (feature 57 not in {0.0})
#      If (feature 2 in {0.0})
#       If (feature 30 in {0.0})
#        If (feature 4 in {0.0})
#         If (feature 1 in {0.0})
#          Predict: 0.023559683403348755
#         Else (feature 1 not in {0.0})
#          Predict: 0.32147160441749517
#        Else (feature 4 not in {0.0})
#         If (feature 66 <= 6.5)
#          Predict: 0.8767197885324096
#         Else (feature 66 > 6.5)
#          Predict: 0.11150418669951426
#       Else (feature 30 not in {0.0})
#        If (feature 41 in {1.0})
#         If (feature 60 in {0.0})
#          Predict: -1.7780679516943234
#         Else (feature 60 not in {0.0})
#          Predict: 1.0589889065096096
#        Else (feature 41 not in {1.0})
#         If (feature 66 <= 3.5)
#          Predict: -2.0323454869204363
#         Else (feature 66 > 3.5)
#          Predict: 0.9200453841857253
#      Else (feature 2 not in {0.0})
#       If (feature 17 in {0.0})
#        If (feature 38 in {1.0})
#         If (feature 64 <= 224.5)
#          Predict: -0.7379644788586105
#         Else (feature 64 > 224.5)
#          Predict: 2.691752528757849
#        Else (feature 38 not in {1.0})
#         If (feature 66 <= 25.5)
#          Predict: 0.5482866499837681
#         Else (feature 66 > 25.5)
#          Predict: -0.5272443963532751
#       Else (feature 17 not in {0.0})
#        If (feature 60 in {0.0})
#         If (feature 66 <= 9.5)
#          Predict: 1.6814949122325373
#         Else (feature 66 > 9.5)
#          Predict: 1.836887558264765
#        Else (feature 60 not in {0.0})
#         If (feature 64 <= 134.5)
#          Predict: 2.1029571772479985
#         Else (feature 64 > 134.5)
#          Predict: 2.1914042979807284
#   Tree 18 (weight 0.1):
#     If (feature 5 in {1.0})
#      If (feature 24 in {0.0})
#       If (feature 15 in {0.0})
#        If (feature 19 in {0.0})
#         If (feature 66 <= 19.5)
#          Predict: -0.09271533180310203
#         Else (feature 66 > 19.5)
#          Predict: -0.39663519586029944
#        Else (feature 19 not in {0.0})
#         If (feature 49 in {0.0})
#          Predict: 0.05966238320805381
#         Else (feature 49 not in {0.0})
#          Predict: 0.7446360138919919
#       Else (feature 15 not in {0.0})
#        If (feature 58 in {0.0})
#         If (feature 53 in {1.0})
#          Predict: -0.5647881136176139
#         Else (feature 53 not in {1.0})
#          Predict: 0.2527075634427167
#        Else (feature 58 not in {0.0})
#         If (feature 65 <= 541.5)
#          Predict: 2.8864523356376215
#         Else (feature 65 > 541.5)
#          Predict: 2.3111247737078857
#      Else (feature 24 not in {0.0})
#       If (feature 47 in {0.0})
#        If (feature 68 <= 47.5)
#         If (feature 59 in {0.0})
#          Predict: -1.065386472987421
#         Else (feature 59 not in {0.0})
#          Predict: 0.8736125122503813
#        Else (feature 68 > 47.5)
#         If (feature 64 <= 98.5)
#          Predict: 0.7483989765545829
#         Else (feature 64 > 98.5)
#          Predict: -0.1109516032746187
#       Else (feature 47 not in {0.0})
#        If (feature 69 <= 133.5)
#         If (feature 65 <= 602.5)
#          Predict: 1.1640819304782666
#         Else (feature 65 > 602.5)
#          Predict: -1.5357231874691617
#        Else (feature 69 > 133.5)
#         If (feature 60 in {0.0})
#          Predict: 1.3915553723233212
#         Else (feature 60 not in {0.0})
#          Predict: 2.668045337698969
#     Else (feature 5 not in {1.0})
#      If (feature 25 in {1.0})
#       If (feature 55 in {1.0})
#        If (feature 65 <= 178.0)
#         Predict: 2.6802730972008306
#        Else (feature 65 > 178.0)
#         If (feature 68 <= 54.5)
#          Predict: -1.0740709834220818
#         Else (feature 68 > 54.5)
#          Predict: -0.38473934260511294
#       Else (feature 55 not in {1.0})
#        If (feature 10 in {1.0})
#         If (feature 64 <= 277.5)
#          Predict: -0.35134418218403846
#         Else (feature 64 > 277.5)
#          Predict: 0.7766399976786383
#        Else (feature 10 not in {1.0})
#         If (feature 41 in {0.0})
#          Predict: -0.1381147278743342
#         Else (feature 41 not in {0.0})
#          Predict: 0.11524684208046967
#      Else (feature 25 not in {1.0})
#       If (feature 8 in {1.0})
#        If (feature 47 in {0.0})
#         If (feature 65 <= 123.5)
#          Predict: 0.2686972761614163
#         Else (feature 65 > 123.5)
#          Predict: -0.10577807298458138
#        Else (feature 47 not in {0.0})
#         If (feature 36 in {1.0})
#          Predict: -0.4959509134844999
#         Else (feature 36 not in {1.0})
#          Predict: 0.061918957327094085
#       Else (feature 8 not in {1.0})
#        If (feature 59 in {1.0})
#         If (feature 60 in {1.0})
#          Predict: -0.4325204836631207
#         Else (feature 60 not in {1.0})
#          Predict: -0.13464422462176365
#        Else (feature 59 not in {1.0})
#         If (feature 29 in {1.0})
#          Predict: -0.11031887946435061
#         Else (feature 29 not in {1.0})
#          Predict: 0.02159414971825032
#   Tree 19 (weight 0.1):
#     If (feature 22 in {1.0})
#      If (feature 9 in {0.0})
#       If (feature 0 in {0.0})
#        If (feature 59 in {0.0})
#         If (feature 1 in {0.0})
#          Predict: -0.24594748458208004
#         Else (feature 1 not in {0.0})
#          Predict: 0.10039595980760516
#        Else (feature 59 not in {0.0})
#         If (feature 5 in {0.0})
#          Predict: 0.5182834325179638
#         Else (feature 5 not in {0.0})
#          Predict: 2.306147893662312
#       Else (feature 0 not in {0.0})
#        If (feature 53 in {0.0})
#         If (feature 57 in {0.0})
#          Predict: 0.11856953689852495
#         Else (feature 57 not in {0.0})
#          Predict: 1.6839093049464111
#        Else (feature 53 not in {0.0})
#         If (feature 66 <= 11.5)
#          Predict: 0.8164473877214771
#         Else (feature 66 > 11.5)
#          Predict: 2.9426639754245545
#      Else (feature 9 not in {0.0})
#       If (feature 53 in {0.0})
#        If (feature 61 in {0.0})
#         If (feature 69 <= 127.5)
#          Predict: -0.18103180541901692
#         Else (feature 69 > 127.5)
#          Predict: 0.5175662625848597
#        Else (feature 61 not in {0.0})
#         If (feature 67 <= 23.5)
#          Predict: 0.5579520406348553
#         Else (feature 67 > 23.5)
#          Predict: 1.8085673158721118
#       Else (feature 53 not in {0.0})
#        If (feature 66 <= 2.5)
#         If (feature 64 <= 64.5)
#          Predict: -1.7578390239233888
#         Else (feature 64 > 64.5)
#          Predict: -1.9857136864994556
#        Else (feature 66 > 2.5)
#         If (feature 69 <= 127.5)
#          Predict: 2.0596333612519313
#         Else (feature 69 > 127.5)
#          Predict: -0.16896265965502266
#     Else (feature 22 not in {1.0})
#      If (feature 41 in {1.0})
#       If (feature 40 in {0.0})
#        If (feature 9 in {1.0})
#         If (feature 62 in {1.0})
#          Predict: -0.7308920573374827
#         Else (feature 62 not in {1.0})
#          Predict: -0.3722470155477164
#        Else (feature 9 not in {1.0})
#         If (feature 0 in {0.0})
#          Predict: -0.07485316373417861
#         Else (feature 0 not in {0.0})
#          Predict: 0.20270812821017778
#       Else (feature 40 not in {0.0})
#        If (feature 7 in {0.0})
#         If (feature 54 in {0.0})
#          Predict: 0.0564732826963897
#         Else (feature 54 not in {0.0})
#          Predict: 1.8596114345503967
#        Else (feature 7 not in {0.0})
#         If (feature 69 <= 182.5)
#          Predict: 1.204351131537658
#         Else (feature 69 > 182.5)
#          Predict: 0.3679484818295983
#      Else (feature 41 not in {1.0})
#       If (feature 40 in {1.0})
#        If (feature 54 in {0.0})
#         If (feature 2 in {0.0})
#          Predict: -0.23339910098065983
#         Else (feature 2 not in {0.0})
#          Predict: 0.1233094585953807
#        Else (feature 54 not in {0.0})
#         If (feature 4 in {1.0})
#          Predict: -0.9674970761872297
#         Else (feature 4 not in {1.0})
#          Predict: 0.5989895672482128
#       Else (feature 40 not in {1.0})
#        If (feature 45 in {1.0})
#         If (feature 29 in {1.0})
#          Predict: -0.40440506055021985
#         Else (feature 29 not in {1.0})
#          Predict: -0.011242641722028296
#        Else (feature 45 not in {1.0})
#         If (feature 38 in {1.0})
#          Predict: -0.16474674114051865
#         Else (feature 38 not in {1.0})
#          Predict: 0.029748065718434143
#
#     idx                        name     score
# 66   60  DEPT_TIME_FLAG_vec_Morning  0.102077
# 3    67                    TAXI_OUT  0.071733
# 53   47              AIRLINE_vec_WN  0.052292

# %% [markdown]
# ### 2.4.2 Multiclass Classification tasks<a class="anchor" id="2.4.2"></a>
# Multiclass classification task (using Naive Bayes) for only arrival delay classification (1 model).

# %% [markdown]
# a. Write code to use the corresponding ML Pipelines to train the model on the training data (Use fit/transform here). This label is generated from task 1.3.1.b.

# %%
# For the Multiclass classification arrival
pipelineModel_nb_arr = pipeline_nb_arr.fit(train)
predictions_nb_arr = pipelineModel_nb_arr.transform(test)

# %% [markdown]
# b. Write code to display the count of each combination of early/on-time/late label and prediction label in formats as shown in the example Fig.2.

# %%
# For the Multiclass classification arrival
print("Multiclass classification arrival")
combination_nb_arr = predictions_nb_arr.groupby('multiClassArrDelay', 'prediction')
combination_nb_arr = combination_nb_arr.agg(F.count('multiClassArrDelay').alias('count'))
combination_nb_arr.withColumnRenamed('multiClassArrDelay', 'late (arrival)').show()
# Out:
# Multiclass classification arrival
# +--------------+----------+------+
# |late (arrival)|prediction| count|
# +--------------+----------+------+
# |             2|       1.0|  1235|
# |             1|       0.0| 31372|
# |             0|       2.0|119802|
# |             0|       0.0|199936|
# |             1|       2.0| 33158|
# |             2|       2.0| 35274|
# |             1|       1.0|  1627|
# |             2|       0.0| 31878|
# |             0|       1.0|  3201|
# +--------------+----------+------+

# %% [markdown]
# c. Compute the AUC, accuracy, recall, and precision for the early/on-time/late label from Naive Bayes model from pyspark MLlib/ML APIs.

# %%
print("Multiclass classification arrival")
   
#calculating AUC
evaluator = BinaryClassificationEvaluator(rawPredictionCol="rawPrediction", labelCol = 'multiClassArrDelay' , metricName = 'areaUnderROC')
auc = evaluator.evaluate(predictions_nb_arr)
print("AUC: "+str(auc))
    
# calculating accuracy
evaluator = MulticlassClassificationEvaluator(predictionCol='prediction', labelCol='multiClassArrDelay', metricName='accuracy')
accuracy = evaluator.evaluate(predictions_nb_arr)
print("Accuracy: "+str(accuracy))
    
#calculating precision
evaluator = MulticlassClassificationEvaluator(predictionCol='prediction', labelCol='multiClassArrDelay', metricName='precisionByLabel')
precision = evaluator.evaluate(predictions_nb_arr)
print("Precision: "+str(precision))
    
#calculating recall
evaluator = MulticlassClassificationEvaluator(predictionCol='prediction', labelCol='multiClassArrDelay', metricName='recallByLabel')
recall = evaluator.evaluate(predictions_nb_arr)
print("Recall: "+str(recall))
# Out:
# Multiclass classification arrival
# AUC: 0.465558450243858
# Accuracy: 0.517695739513818
# Precision: 0.7596756666388029
# Recall: 0.6191138264501965

# %% [markdown]
# d. Discuss which metric is more proper for measuring the model performance on predicting early/on-time/late events, in order to give the performers good recommendations.

# %% [markdown]
#  In my opinion, precision is the most proper metric for measuring the model performance on predicting early/on-time/late events. Precision is the measurement of how many classes are actually positive out of all the positive classes we have predicted. In other words, it measures how many of predicted as 'late' events are actually late.

# %% [markdown]
# e. Discuss the ways the classification performance can be improved.

# %% [markdown]
# As it may be observed from the results is (c), even though the accuracy, precision and recall values are relatively high, the AUC, which is the measure of the ability of a classifier to distinguish between classes, is as low as +-0.442. AUC is an important metric in measuring the performance of a model at distinguishing between the positive and negative classes.
# In order to improve the AUC metric, and the classification performance overall there are several possible approaches:
# 1. Feature normalization and scaling: makes the values of each feature in the data have zero-mean and unit-variance. Improves the performance of the linear model
# 2. Improve class imbalance: as it may be noticed from part (b), occurence of some classes, such as [0, 0.0] is extremely high compared to other classes. The approaches such as setting class weights or performing the data sampling may significantly improve the performance
# 3. Hyperparameter tuning: use algorithms such as grid search or random search to tune the data and hyper-parameters to get a best fit.
